# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa
import pickle, json, requests, base64

# %% [markdown]
# ## Build a scikit-learn model

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data  
Y = iris.target
# print(iris.DESCR)

# %%
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.decomposition import PCA
from sklearn.preprocessing import Imputer, StandardScaler, MinMaxScaler
from sklearn.preprocessing import RobustScaler, MaxAbsScaler

from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier

imputers = [('imputer', Imputer())]
scalers =  [('std_scaler', StandardScaler()), ('minmax_scaler', MinMaxScaler()),
            ('maxabs_scaler', MaxAbsScaler()), ('robust_scaler', RobustScaler())];
pcas = [('pca_4comps', PCA(n_components = 4))]
estimators = [('booster', GradientBoostingClassifier())]
random_state = np.random.RandomState(0)
clf = Pipeline(imputers + scalers + pcas + estimators)

clf.fit(X, Y)
# Out:
# Pipeline(steps=[('imputer', Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0)), ('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('minmax_scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('maxabs_scaler', MaxAbsScaler(copy=True)), ('robust_scaler', ...=100, presort='auto', random_state=None,
#               subsample=1.0, verbose=0, warm_start=False))])

# %%
#clf.__dict__

# %% [markdown]
# ## Generate SQL Code from the Model

# %%
def test_ws_sql_gen(pickle_data):
    WS_URL="https://sklearn2sql.herokuapp.com/model"
    b64_data = base64.b64encode(pickle_data)
    data={"Name":"model1", "PickleData":b64_data , "SQLDialect":"postgresql"}
    r = requests.post(WS_URL, json=data)
    content = r.json()
    # print(content)
    lSQL = content["model"]["SQLGenrationResult"][0]["SQL"]
    return lSQL;

# %%
pickle_data = pickle.dumps(clf)
lSQL = test_ws_sql_gen(pickle_data)
print(lSQL[0:120000])
# Out:
# WITH "ADS_imp_1_OUT" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_0" IS NULL) THEN 5.84333333333 ELSE "ADS"."Feature_0" END AS imputer_output_2, CASE WHEN ("ADS"."Feature_1" IS NULL) THEN 3.054 ELSE "ADS"."Feature_1" END AS imputer_output_3, CASE WHEN ("ADS"."Feature_2" IS NULL) THEN 3.75866666667 ELSE "ADS"."Feature_2" END AS imputer_output_4, CASE WHEN ("ADS"."Feature_3" IS NULL) THEN 1.19866666667 ELSE "ADS"."Feature_3" END AS imputer_output_5
# FROM "INPUT_DATA" AS "ADS"),
# "ADS_std_2_OUT" AS
# (SELECT "ADS_imp_1_OUT"."KEY" AS "KEY", (CAST("ADS_imp_1_OUT".imputer_output_2 AS FLOAT) - 5.84333333333) / 0.825301291785 AS std_scaler_output_2, (CAST("ADS_imp_1_OUT".imputer_output_3 AS FLOAT) - 3.054) / 0.432146580071 AS std_scaler_output_3, (CAST("ADS_imp_1_OUT".imputer_output_4 AS FLOAT) - 3.75866666667) / 1.75852918341 AS std_scaler_output_4, (CAST("ADS_imp_1_OUT".imputer_output_5 AS FLOAT) - 1.19866666667) / 0.760612618588 AS std_scaler_output_5
# FROM "ADS_imp_1_OUT"),
# "ADS_min_3_OUT" AS
# (SELECT "ADS_std_2_OUT"."KEY" AS "KEY", CAST("ADS_std_2_OUT".std_scaler_output_2 AS FLOAT) * 0.229250358829 + 0.428703703704 AS minmax_scaler_output_2, CAST("ADS_std_2_OUT".std_scaler_output_3 AS FLOAT) * 0.180061075029 + 0.439166666667 AS minmax_scaler_output_3, CAST("ADS_std_2_OUT".std_scaler_output_4 AS FLOAT) * 0.298055793798 + 0.467570621469 AS minmax_scaler_output_4, CAST("ADS_std_2_OUT".std_scaler_output_5 AS FLOAT) * 0.316921924412 + 0.457777777778 AS minmax_scaler_output_5
# FROM "ADS_std_2_OUT"),
# "ADS_max_4_OUT" AS
# (SELECT "ADS_min_3_OUT"."KEY" AS "KEY", CAST("ADS_min_3_OUT".minmax_scaler_output_2 AS FLOAT) / 1.0 AS maxabs_scaler_output_2, CAST("ADS_min_3_OUT".minmax_scaler_output_3 AS FLOAT) / 1.0 AS maxabs_scaler_output_3, CAST("ADS_min_3_OUT".minmax_scaler_output_4 AS FLOAT) / 1.0 AS maxabs_scaler_output_4, CAST("ADS_min_3_OUT".minmax_scaler_output_5 AS FLOAT) / 1.0 AS maxabs_scaler_output_5
# FROM "ADS_min_3_OUT"),
# "ADS_rob_5_OUT" AS
# (SELECT "ADS_max_4_OUT"."KEY" AS "KEY", (CAST("ADS_max_4_OUT".maxabs_scaler_output_2 AS FLOAT) - 0.416666666667) / 0.361111111111 AS robust_scaler_output_2, (CAST("ADS_max_4_OUT".maxabs_scaler_output_3 AS FLOAT) - 0.416666666667) / 0.208333333333 AS robust_scaler_output_3, (CAST("ADS_max_4_OUT".maxabs_scaler_output_4 AS FLOAT) - 0.567796610169) / 0.593220338983 AS robust_scaler_output_4, (CAST("ADS_max_4_OUT".maxabs_scaler_output_5 AS FLOAT) - 0.5) / 0.625 AS robust_scaler_output_5
# FROM "ADS_max_4_OUT"),
# "CenteredDataForPCA" AS
# (SELECT "ADS_rob_5_OUT"."KEY" AS "KEY", CAST("ADS_rob_5_OUT".robust_scaler_output_2 AS FLOAT) - 0.0333333333333 AS robust_scaler_output_2, CAST("ADS_rob_5_OUT".robust_scaler_output_3 AS FLOAT) - 0.108 AS robust_scaler_output_3, CAST("ADS_rob_5_OUT".robust_scaler_output_4 AS FLOAT) - -0.168952380952 AS robust_scaler_output_4, CAST("ADS_rob_5_OUT".robust_scaler_output_5 AS FLOAT) - -0.0675555555556 AS robust_scaler_output_5
# FROM "ADS_rob_5_OUT"),
# "ADS_pca_6_OUT" AS
# (SELECT "CenteredDataForPCA"."KEY" AS "KEY", "CenteredDataForPCA".robust_scaler_output_2 * -0.447657317765 + "CenteredDataForPCA".robust_scaler_output_3 * 0.64147212658 + "CenteredDataForPCA".robust_scaler_output_4 * -0.450983672283 + "CenteredDataForPCA".robust_scaler_output_5 * -0.429802470918 AS pca_4comps_output_2, "CenteredDataForPCA".robust_scaler_output_2 * 0.548644834048 + "CenteredDataForPCA".robust_scaler_output_3 * 0.746908939088 + "CenteredDataForPCA".robust_scaler_output_4 * 0.254203875701 + "CenteredDataForPCA".robust_scaler_output_5 * 0.276579594985 AS pca_4comps_output_3, "CenteredDataForPCA".robust_scaler_output_2 * -0.676170469726 + "CenteredDataForPCA".robust_scaler_output_3 * 0.159989073346 + "CenteredDataForPCA".robust_scaler_output_4 * 0.259558177741 + "CenteredDataForPCA".robust_scaler_output_5 * 0.670691094803 AS pca_4comps_output_4, "CenteredDataForPCA".robust_scaler_output_2 * -0.203433693853 + "CenteredDataForPCA".robust_scaler_output_3 * 0.0710214329801 + "CenteredDataForPCA".robust_scaler_output_4 * 0.815244545692 + "CenteredDataForPCA".robust_scaler_output_5 * -0.537537923297 AS pca_4comps_output_5
# FROM "CenteredDataForPCA"),
# "DT_node_lookup" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN 1 ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN 3 ELSE 4 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 3.515706244646329e-16 AS "Estimator" UNION ALL SELECT 1 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 99 AS count, 1 AS depth, 0 AS parent_id, -1.0 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, 0 AS parent_id, 0.6470588235294121 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 50 AS count, 2 AS depth, 2 AS parent_id, 2.0 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, 2 AS parent_id, -0.9999999999999999 AS "Estimator") AS "Values"),
# "DT_Output" AS
# (SELECT "DT_node_lookup"."KEY" AS "KEY", "DT_node_lookup".node_id_2 AS node_id_2, "DT_node_data".node_id AS node_id, "DT_node_data".feature AS feature, "DT_node_data".threshold AS threshold, "DT_node_data".count AS count, "DT_node_data".depth AS depth, "DT_node_data".parent_id AS parent_id, "DT_node_data"."Estimator" AS "Estimator"
# FROM "DT_node_lookup" LEFT OUTER JOIN "DT_node_data" ON "DT_node_lookup".node_id_2 = "DT_node_data".node_id),
# "GB_Tree_0_0" AS
# (SELECT "DT_Output"."KEY" AS "KEY", "DT_Output"."Estimator" AS "Score_0", 0.0 AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output"),
# "DT_node_lookup_1" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.6178238987922668) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.1961124837398529) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_1" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.00035651168661645266 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 101 AS count, 1 AS depth, 0 AS parent_id, 0.15113110546722508 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.6178238987922668 AS threshold, 54 AS count, 2 AS depth, 1 AS parent_id, 0.3785953500395856 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 26 AS count, 3 AS depth, 2 AS parent_id, 0.3463677023519576 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 28 AS count, 3 AS depth, 2 AS parent_id, 1.838051613219892 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.1961124837398529 AS threshold, 47 AS count, 2 AS depth, 1 AS parent_id, -0.11021079255208327 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 43 AS count, 3 AS depth, 5 AS parent_id, -0.5358975011316298 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 4 AS count, 3 AS depth, 5 AS parent_id, 1.9365582786906392 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, 0 AS parent_id, -0.9667773351250147 AS "Estimator") AS "Values"),
# "DT_Output_1" AS
# (SELECT "DT_node_lookup_1"."KEY" AS "KEY", "DT_node_lookup_1".node_id_2 AS node_id_2, "DT_node_data_1".node_id AS node_id, "DT_node_data_1".feature AS feature, "DT_node_data_1".threshold AS threshold, "DT_node_data_1".count AS count, "DT_node_data_1".depth AS depth, "DT_node_data_1".parent_id AS parent_id, "DT_node_data_1"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_1" LEFT OUTER JOIN "DT_node_data_1" ON "DT_node_lookup_1".node_id_2 = "DT_node_data_1".node_id),
# "GB_Tree_0_1" AS
# (SELECT "DT_Output_1"."KEY" AS "KEY", 0.0 AS "Score_0", "DT_Output_1"."Estimator" AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_1"),
# "DT_node_lookup_2" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.4558808207511902) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.02152065373957157) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1462516337633133) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.1800115704536438) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.9675517082214355) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.18666619062423706) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_2" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0010562774898447503 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.4558808207511902 AS threshold, 44 AS count, 1 AS depth, 0 AS parent_id, 0.42738882084746166 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.02152065373957157 AS threshold, 9 AS count, 2 AS depth, 1 AS parent_id, -0.1179044582108525 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, 2 AS parent_id, -0.6390013081196498 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 2 AS parent_id, 1.960054018161165 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, 0.1462516337633133 AS threshold, 35 AS count, 2 AS depth, 1 AS parent_id, 0.5676070926053136 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 13 AS count, 3 AS depth, 5 AS parent_id, 1.2745888771640264 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 22 AS count, 3 AS depth, 5 AS parent_id, 1.9017721921279367 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.1800115704536438 AS threshold, 106 AS count, 1 AS depth, 0 AS parent_id, -0.1759119480548264 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, 1.9675517082214355 AS threshold, 88 AS count, 2 AS depth, 8 AS parent_id, -0.27879926029041135 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 86 AS count, 3 AS depth, 9 AS parent_id, -0.915279481566999 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 9 AS parent_id, 1.9017721921279374 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_2' AS feature, -0.18666619062423706 AS threshold, 18 AS count, 2 AS depth, 8 AS parent_id, 0.3270926895413655 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 13 AS count, 3 AS depth, 12 AS parent_id, 1.6967488725236313 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 5 AS count, 3 AS depth, 12 AS parent_id, -0.9817477403845429 AS "Estimator") AS "Values"),
# "DT_Output_2" AS
# (SELECT "DT_node_lookup_2"."KEY" AS "KEY", "DT_node_lookup_2".node_id_2 AS node_id_2, "DT_node_data_2".node_id AS node_id, "DT_node_data_2".feature AS feature, "DT_node_data_2".threshold AS threshold, "DT_node_data_2".count AS count, "DT_node_data_2".depth AS depth, "DT_node_data_2".parent_id AS parent_id, "DT_node_data_2"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_2" LEFT OUTER JOIN "DT_node_data_2" ON "DT_node_lookup_2".node_id_2 = "DT_node_data_2".node_id),
# "GB_Tree_0_2" AS
# (SELECT "DT_Output_2"."KEY" AS "KEY", 0.0 AS "Score_0", 0.0 AS "Score_1", "DT_Output_2"."Estimator" AS "Score_2"
# FROM "DT_Output_2"),
# "DT_node_lookup_3" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7213706970214844) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.108229398727417) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4274854063987732) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_3" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.001072848461565085 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.22600841522216797 AS threshold, 99 AS count, 1 AS depth, 0 AS parent_id, -0.30120537754117643 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.7213706970214844 AS threshold, 19 AS count, 2 AS depth, 1 AS parent_id, -0.30864653263091457 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 11 AS count, 3 AS depth, 2 AS parent_id, -0.953419682730699 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, 2 AS parent_id, -0.9808754095446927 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, -1.108229398727417 AS threshold, 80 AS count, 2 AS depth, 1 AS parent_id, -0.2994381032073639 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, 5 AS parent_id, -0.9643391102175451 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 73 AS count, 3 AS depth, 5 AS parent_id, -0.950725394195762 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, 0 AS parent_id, 0.5815373550459159 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_2' AS feature, 0.4274854063987732 AS threshold, 50 AS count, 2 AS depth, 8 AS parent_id, 0.5991504856942133 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 9 AS parent_id, 1.8207044835470025 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, 9 AS parent_id, 1.6602023777818735 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, 8 AS parent_id, -0.9511840603143531 AS "Estimator") AS "Values"),
# "DT_Output_3" AS
# (SELECT "DT_node_lookup_3"."KEY" AS "KEY", "DT_node_lookup_3".node_id_2 AS node_id_2, "DT_node_data_3".node_id AS node_id, "DT_node_data_3".feature AS feature, "DT_node_data_3".threshold AS threshold, "DT_node_data_3".count AS count, "DT_node_data_3".depth AS depth, "DT_node_data_3".parent_id AS parent_id, "DT_node_data_3"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_3" LEFT OUTER JOIN "DT_node_data_3" ON "DT_node_lookup_3".node_id_2 = "DT_node_data_3".node_id),
# "GB_Tree_1_0" AS
# (SELECT "DT_Output_3"."KEY" AS "KEY", "DT_Output_3"."Estimator" AS "Score_0", 0.0 AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_3"),
# "DT_node_lookup_4" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.6178238987922668) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.1961124837398529) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_4" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0008036934736950973 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 101 AS count, 1 AS depth, 0 AS parent_id, 0.13620533464782525 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.6178238987922668 AS threshold, 54 AS count, 2 AS depth, 1 AS parent_id, 0.3412329384320369 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 26 AS count, 3 AS depth, 2 AS parent_id, 0.31141141692862967 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 28 AS count, 3 AS depth, 2 AS parent_id, 1.5471145399986113 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.1961124837398529 AS threshold, 47 AS count, 2 AS depth, 1 AS parent_id, -0.09935829523190735 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 43 AS count, 3 AS depth, 5 AS parent_id, -0.4958499247908455 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 4 AS count, 3 AS depth, 5 AS parent_id, 1.618196935382296 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, 0 AS parent_id, -0.923731428008898 AS "Estimator") AS "Values"),
# "DT_Output_4" AS
# (SELECT "DT_node_lookup_4"."KEY" AS "KEY", "DT_node_lookup_4".node_id_2 AS node_id_2, "DT_node_data_4".node_id AS node_id, "DT_node_data_4".feature AS feature, "DT_node_data_4".threshold AS threshold, "DT_node_data_4".count AS count, "DT_node_data_4".depth AS depth, "DT_node_data_4".parent_id AS parent_id, "DT_node_data_4"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_4" LEFT OUTER JOIN "DT_node_data_4" ON "DT_node_lookup_4".node_id_2 = "DT_node_data_4".node_id),
# "GB_Tree_1_1" AS
# (SELECT "DT_Output_4"."KEY" AS "KEY", 0.0 AS "Score_0", "DT_Output_4"."Estimator" AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_4"),
# "DT_node_lookup_5" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.4558808207511902) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.17407992482185364) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.40767401456832886) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.1800115704536438) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.9675517082214355) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.18666619062423706) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_5" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0014960298656148238 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.4558808207511902 AS threshold, 44 AS count, 1 AS depth, 0 AS parent_id, 0.3865362111086924 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.17407992482185364 AS threshold, 9 AS count, 2 AS depth, 1 AS parent_id, -0.11610166797058216 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, 2 AS parent_id, -0.6381290346295917 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 2 AS parent_id, 2.010352223872432 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.40767401456832886 AS threshold, 35 AS count, 2 AS depth, 1 AS parent_id, 0.5157859514433629 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 5 AS parent_id, 0.29706679037880906 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 33 AS count, 3 AS depth, 5 AS parent_id, 1.5051971496737622 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.1800115704536438 AS threshold, 106 AS count, 1 AS depth, 0 AS parent_id, -0.15833196989566276 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, 1.9675517082214355 AS threshold, 88 AS count, 2 AS depth, 8 AS parent_id, -0.25175257696566544 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 86 AS count, 3 AS depth, 9 AS parent_id, -0.8719460246831333 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 9 AS parent_id, 1.616677477587012 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_2' AS feature, -0.18666619062423706 AS threshold, 18 AS count, 2 AS depth, 8 AS parent_id, 0.29839099800212754 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 13 AS count, 3 AS depth, 12 AS parent_id, 1.4577116342553889 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 5 AS count, 3 AS depth, 12 AS parent_id, -0.9359901342417474 AS "Estimator") AS "Values"),
# "DT_Output_5" AS
# (SELECT "DT_node_lookup_5"."KEY" AS "KEY", "DT_node_lookup_5".node_id_2 AS node_id_2, "DT_node_data_5".node_id AS node_id, "DT_node_data_5".feature AS feature, "DT_node_data_5".threshold AS threshold, "DT_node_data_5".count AS count, "DT_node_data_5".depth AS depth, "DT_node_data_5".parent_id AS parent_id, "DT_node_data_5"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_5" LEFT OUTER JOIN "DT_node_data_5" ON "DT_node_lookup_5".node_id_2 = "DT_node_data_5".node_id),
# "GB_Tree_1_2" AS
# (SELECT "DT_Output_5"."KEY" AS "KEY", 0.0 AS "Score_0", 0.0 AS "Score_1", "DT_Output_5"."Estimator" AS "Score_2"
# FROM "DT_Output_5"),
# "DT_node_lookup_6" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7213706970214844) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.108229398727417) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= -0.13445144891738892) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_6" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.0024225850016555603 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.22600841522216797 AS threshold, 99 AS count, 1 AS depth, 0 AS parent_id, -0.2722275286983896 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.7213706970214844 AS threshold, 19 AS count, 2 AS depth, 1 AS parent_id, -0.28765795713611203 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 11 AS count, 3 AS depth, 2 AS parent_id, -0.9191352224637981 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, 2 AS parent_id, -0.9641097722824493 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, -1.108229398727417 AS threshold, 80 AS count, 2 AS depth, 1 AS parent_id, -0.2685628019444306 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, 5 AS parent_id, -0.9336976113336845 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 73 AS count, 3 AS depth, 5 AS parent_id, -0.910391850158937 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, 0 AS parent_id, 0.5213164233508282 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_5' AS feature, -0.13445144891738892 AS threshold, 50 AS count, 2 AS depth, 8 AS parent_id, 0.5370937320157799 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 9 AS parent_id, 1.6854248594522 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, 9 AS parent_id, 1.4359125573144749 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, 8 AS parent_id, -0.9101860406696928 AS "Estimator") AS "Values"),
# "DT_Output_6" AS
# (SELECT "DT_node_lookup_6"."KEY" AS "KEY", "DT_node_lookup_6".node_id_2 AS node_id_2, "DT_node_data_6".node_id AS node_id, "DT_node_data_6".feature AS feature, "DT_node_data_6".threshold AS threshold, "DT_node_data_6".count AS count, "DT_node_data_6".depth AS depth, "DT_node_data_6".parent_id AS parent_id, "DT_node_data_6"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_6" LEFT OUTER JOIN "DT_node_data_6" ON "DT_node_lookup_6".node_id_2 = "DT_node_data_6".node_id),
# "GB_Tree_2_0" AS
# (SELECT "DT_Output_6"."KEY" AS "KEY", "DT_Output_6"."Estimator" AS "Score_0", 0.0 AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_6"),
# "DT_node_lookup_7" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.7124893665313721) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.3935815691947937) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_7" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0014542185797956715 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.7124893665313721 AS threshold, 101 AS count, 1 AS depth, 0 AS parent_id, 0.12280819233749192 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 79 AS count, 2 AS depth, 1 AS parent_id, 0.22866188789819286 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 33 AS count, 3 AS depth, 2 AS parent_id, -0.10663851849697281 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 46 AS count, 3 AS depth, 2 AS parent_id, 1.154084085733713 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.3935815691947937 AS threshold, 22 AS count, 2 AS depth, 1 AS parent_id, -0.25730280535775196 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 5 AS parent_id, 0.48701299780239615 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 20 AS count, 3 AS depth, 5 AS parent_id, -0.9524067491968948 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, 0 AS parent_id, -0.8873314650117936 AS "Estimator") AS "Values"),
# "DT_Output_7" AS
# (SELECT "DT_node_lookup_7"."KEY" AS "KEY", "DT_node_lookup_7".node_id_2 AS node_id_2, "DT_node_data_7".node_id AS node_id, "DT_node_data_7".feature AS feature, "DT_node_data_7".threshold AS threshold, "DT_node_data_7".count AS count, "DT_node_data_7".depth AS depth, "DT_node_data_7".parent_id AS parent_id, "DT_node_data_7"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_7" LEFT OUTER JOIN "DT_node_data_7" ON "DT_node_lookup_7".node_id_2 = "DT_node_data_7".node_id),
# "GB_Tree_2_1" AS
# (SELECT "DT_Output_7"."KEY" AS "KEY", 0.0 AS "Score_0", "DT_Output_7"."Estimator" AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_7"),
# "DT_node_lookup_8" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.4757063388824463) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.6644308567047119) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.031499482691287994) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.12673455476760864) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.7185304164886475) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.47118985652923584) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.08170110732316971) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_8" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.4757063388824463 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0020423013205152717 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.6644308567047119 AS threshold, 63 AS count, 1 AS depth, 0 AS parent_id, 0.26431415247854545 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.031499482691287994 AS threshold, 14 AS count, 2 AS depth, 1 AS parent_id, -0.17318470134030872 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 11 AS count, 3 AS depth, 2 AS parent_id, -0.9632040203964939 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 3 AS count, 3 AS depth, 2 AS parent_id, 0.925261833565572 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.12673455476760864 AS threshold, 49 AS count, 2 AS depth, 1 AS parent_id, 0.3893138249982181 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 17 AS count, 3 AS depth, 5 AS parent_id, 0.37592866892199783 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 32 AS count, 3 AS depth, 5 AS parent_id, 1.427389342794079 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_3' AS feature, 1.7185304164886475 AS threshold, 87 AS count, 1 AS depth, 0 AS parent_id, -0.18787869434564464 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_4' AS feature, 0.47118985652923584 AS threshold, 84 AS count, 2 AS depth, 8 AS parent_id, -0.21343397229847305 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 82 AS count, 3 AS depth, 9 AS parent_id, -0.7916398122384111 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 9 AS parent_id, 1.4307590879903778 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_4' AS feature, 0.08170110732316971 AS threshold, 3 AS count, 2 AS depth, 8 AS parent_id, 0.5276690883335516 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 12 AS parent_id, 1.4019759519528434 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 12 AS parent_id, 1.4307590879903778 AS "Estimator") AS "Values"),
# "DT_Output_8" AS
# (SELECT "DT_node_lookup_8"."KEY" AS "KEY", "DT_node_lookup_8".node_id_2 AS node_id_2, "DT_node_data_8".node_id AS node_id, "DT_node_data_8".feature AS feature, "DT_node_data_8".threshold AS threshold, "DT_node_data_8".count AS count, "DT_node_data_8".depth AS depth, "DT_node_data_8".parent_id AS parent_id, "DT_node_data_8"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_8" LEFT OUTER JOIN "DT_node_data_8" ON "DT_node_lookup_8".node_id_2 = "DT_node_data_8".node_id),
# "GB_Tree_2_2" AS
# (SELECT "DT_Output_8"."KEY" AS "KEY", 0.0 AS "Score_0", 0.0 AS "Score_1", "DT_Output_8"."Estimator" AS "Score_2"
# FROM "DT_Output_8"),
# "DT_node_lookup_9" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.037814125418663025) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.108229398727417) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.616089940071106) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_9" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.0037694067450108858 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.22600841522216797 AS threshold, 99 AS count, 1 AS depth, 0 AS parent_id, -0.24612393935062482 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.037814125418663025 AS threshold, 19 AS count, 2 AS depth, 1 AS parent_id, -0.2658215844530575 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 14 AS count, 3 AS depth, 2 AS parent_id, -0.9203276748797968 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 5 AS count, 3 AS depth, 2 AS parent_id, -0.8821894523410839 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, -1.108229398727417 AS threshold, 80 AS count, 2 AS depth, 1 AS parent_id, -0.2414457486387971 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, 5 AS parent_id, -0.9109128907261093 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 73 AS count, 3 AS depth, 5 AS parent_id, -0.8773146940370325 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, 0 AS parent_id, 0.4666835094894164 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, -1.616089940071106 AS threshold, 50 AS count, 2 AS depth, 8 AS parent_id, 0.48083967451445875 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 9 AS parent_id, 1.5689102540033268 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, 9 AS parent_id, 1.279385691674107 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, 8 AS parent_id, -0.8784930849046085 AS "Estimator") AS "Values"),
# "DT_Output_9" AS
# (SELECT "DT_node_lookup_9"."KEY" AS "KEY", "DT_node_lookup_9".node_id_2 AS node_id_2, "DT_node_data_9".node_id AS node_id, "DT_node_data_9".feature AS feature, "DT_node_data_9".threshold AS threshold, "DT_node_data_9".count AS count, "DT_node_data_9".depth AS depth, "DT_node_data_9".parent_id AS parent_id, "DT_node_data_9"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_9" LEFT OUTER JOIN "DT_node_data_9" ON "DT_node_lookup_9".node_id_2 = "DT_node_data_9".node_id),
# "GB_Tree_3_0" AS
# (SELECT "DT_Output_9"."KEY" AS "KEY", "DT_Output_9"."Estimator" AS "Score_0", 0.0 AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_9"),
# "DT_node_lookup_10" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.32208648324012756) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_10" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.002036784874308142 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 101 AS count, 1 AS depth, 0 AS parent_id, 0.11041960063390469 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.32208648324012756 AS threshold, 54 AS count, 2 AS depth, 1 AS parent_id, 0.2830050750453719 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 47 AS count, 3 AS depth, 2 AS parent_id, 0.9877595449850841 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, 2 AS parent_id, -0.6446621589849816 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 47 AS count, 2 AS depth, 1 AS parent_id, -0.08787009337075982 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 22 AS count, 3 AS depth, 5 AS parent_id, -0.9240550813252659 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 25 AS count, 3 AS depth, 5 AS parent_id, 0.2377305126430557 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, 0 AS parent_id, -0.8561987276092416 AS "Estimator") AS "Values"),
# "DT_Output_10" AS
# (SELECT "DT_node_lookup_10"."KEY" AS "KEY", "DT_node_lookup_10".node_id_2 AS node_id_2, "DT_node_data_10".node_id AS node_id, "DT_node_data_10".feature AS feature, "DT_node_data_10".threshold AS threshold, "DT_node_data_10".count AS count, "DT_node_data_10".depth AS depth, "DT_node_data_10".parent_id AS parent_id, "DT_node_data_10"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_10" LEFT OUTER JOIN "DT_node_data_10" ON "DT_node_lookup_10".node_id_2 = "DT_node_data_10".node_id),
# "GB_Tree_3_1" AS
# (SELECT "DT_Output_10"."KEY" AS "KEY", 0.0 AS "Score_0", "DT_Output_10"."Estimator" AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_10"),
# "DT_node_lookup_11" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7043026685714722) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.4558808207511902) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.02152065373957157) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.856364369392395) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.1800115704536438) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.9675517082214355) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.18666619062423706) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_11" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.7043026685714722 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0027891888778008396 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.4558808207511902 AS threshold, 42 AS count, 1 AS depth, 0 AS parent_id, 0.32662372030649156 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.02152065373957157 AS threshold, 8 AS count, 2 AS depth, 1 AS parent_id, -0.0852758613226491 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, 2 AS parent_id, -0.5606947910501225 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 2 AS parent_id, 1.6541486394415028 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.856364369392395 AS threshold, 34 AS count, 2 AS depth, 1 AS parent_id, 0.4235412689251128 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 17 AS count, 3 AS depth, 5 AS parent_id, 1.3735455844645557 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 17 AS count, 3 AS depth, 5 AS parent_id, 0.8983370185560907 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.1800115704536438 AS threshold, 108 AS count, 1 AS depth, 0 AS parent_id, -0.12314646223335658 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, 1.9675517082214355 AS threshold, 90 AS count, 2 AS depth, 8 AS parent_id, -0.19923224114331234 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 88 AS count, 3 AS depth, 9 AS parent_id, -0.7734807193160103 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 9 AS parent_id, 1.2881521943450467 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_2' AS feature, -0.18666619062423706 AS threshold, 18 AS count, 2 AS depth, 8 AS parent_id, 0.2572824323164224 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 13 AS count, 3 AS depth, 12 AS parent_id, 1.215636837659677 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 5 AS count, 3 AS depth, 12 AS parent_id, -0.8826104668509851 AS "Estimator") AS "Values"),
# "DT_Output_11" AS
# (SELECT "DT_node_lookup_11"."KEY" AS "KEY", "DT_node_lookup_11".node_id_2 AS node_id_2, "DT_node_data_11".node_id AS node_id, "DT_node_data_11".feature AS feature, "DT_node_data_11".threshold AS threshold, "DT_node_data_11".count AS count, "DT_node_data_11".depth AS depth, "DT_node_data_11".parent_id AS parent_id, "DT_node_data_11"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_11" LEFT OUTER JOIN "DT_node_data_11" ON "DT_node_lookup_11".node_id_2 = "DT_node_data_11".node_id),
# "GB_Tree_3_2" AS
# (SELECT "DT_Output_11"."KEY" AS "KEY", 0.0 AS "Score_0", 0.0 AS "Score_1", "DT_Output_11"."Estimator" AS "Score_2"
# FROM "DT_Output_11"),
# "DT_node_lookup_12" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.037814125418663025) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.108229398727417) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= -0.13445144891738892) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_12" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# ...
# "DT_Output_27" AS
# (SELECT "DT_node_lookup_27"."KEY" AS "KEY", "DT_node_lookup_27".node_id_2 AS node_id_2, "DT_node_data_27".node_id AS node_id, "DT_node_data_27".feature AS feature, "DT_node_data_27".threshold AS threshold, "DT_node_data_27".count AS count, "DT_node_data_27".depth AS depth, "DT_node_data_27".parent_id AS parent_id, "DT_node_data_27"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_27" LEFT OUTER JOIN "DT_node_data_27" ON "DT_node_lookup_27".node_id_2 = "DT_node_data_27".node_id),
# "GB_Tree_9_0" AS
# (SELECT "DT_Output_27"."KEY" AS "KEY", "DT_Output_27"."Estimator" AS "Score_0", 0.0 AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_27"),
# "DT_node_lookup_28" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.32208648324012756) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.031633276492357254) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4274854063987732) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_28" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0050103350848040495 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 99 AS count, 1 AS depth, 0 AS parent_id, 0.06100817620750407 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.32208648324012756 AS threshold, 53 AS count, 2 AS depth, 1 AS parent_id, 0.16683273110057784 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 46 AS count, 3 AS depth, 2 AS parent_id, 0.6727136179657732 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, 2 AS parent_id, -0.5014994932420287 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.031633276492357254 AS threshold, 46 AS count, 2 AS depth, 1 AS parent_id, -0.06092011529973311 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 19 AS count, 3 AS depth, 5 AS parent_id, 0.2577451893612464 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 27 AS count, 3 AS depth, 5 AS parent_id, -0.6673896469374041 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, 0 AS parent_id, -0.1036913565063196 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_2' AS feature, 0.4274854063987732 AS threshold, 50 AS count, 2 AS depth, 8 AS parent_id, -0.11151721403851526 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 9 AS parent_id, -1.0166241020920384 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, 9 AS parent_id, -0.7463533068958051 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, 8 AS parent_id, 0.9358058523138477 AS "Estimator") AS "Values"),
# "DT_Output_28" AS
# (SELECT "DT_node_lookup_28"."KEY" AS "KEY", "DT_node_lookup_28".node_id_2 AS node_id_2, "DT_node_data_28".node_id AS node_id, "DT_node_data_28".feature AS feature, "DT_node_data_28".threshold AS threshold, "DT_node_data_28".count AS count, "DT_node_data_28".depth AS depth, "DT_node_data_28".parent_id AS parent_id, "DT_node_data_28"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_28" LEFT OUTER JOIN "DT_node_data_28" ON "DT_node_lookup_28".node_id_2 = "DT_node_data_28".node_id),
# "GB_Tree_9_1" AS
# (SELECT "DT_Output_28"."KEY" AS "KEY", 0.0 AS "Score_0", "DT_Output_28"."Estimator" AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_28"),
# "DT_node_lookup_29" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7043026685714722) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.4558808207511902) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.02152065373957157) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.8734555244445801) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.12194941937923431) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.9675517082214355) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.4139452874660492) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_29" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.7043026685714722 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.005856508774672077 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.4558808207511902 AS threshold, 42 AS count, 1 AS depth, 0 AS parent_id, 0.1781310845913866 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.02152065373957157 AS threshold, 8 AS count, 2 AS depth, 1 AS parent_id, -0.12358864963112803 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, 2 AS parent_id, -0.6458414735662474 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 2 AS parent_id, 1.2987214809761907 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.8734555244445801 AS threshold, 34 AS count, 2 AS depth, 1 AS parent_id, 0.24912396323197825 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 16 AS count, 3 AS depth, 5 AS parent_id, 1.049645923303961 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 18 AS count, 3 AS depth, 5 AS parent_id, 0.5177253408706624 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.12194941937923431 AS threshold, 108 AS count, 1 AS depth, 0 AS parent_id, -0.061139159598494655 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, 1.9675517082214355 AS threshold, 82 AS count, 2 AS depth, 8 AS parent_id, -0.11491537560149058 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 80 AS count, 3 AS depth, 9 AS parent_id, -0.7299299378663162 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, 9 AS parent_id, 0.9071338253980239 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_2' AS feature, -0.4139452874660492 AS threshold, 26 AS count, 2 AS depth, 8 AS parent_id, 0.10846275241095397 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 12 AS count, 3 AS depth, 12 AS parent_id, 1.0198447596029978 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 14 AS count, 3 AS depth, 12 AS parent_id, -0.4015291686313579 AS "Estimator") AS "Values"),
# "DT_Output_29" AS
# (SELECT "DT_node_lookup_29"."KEY" AS "KEY", "DT_node_lookup_29".node_id_2 AS node_id_2, "DT_node_data_29".node_id AS node_id, "DT_node_data_29".feature AS feature, "DT_node_data_29".threshold AS threshold, "DT_node_data_29".count AS count, "DT_node_data_29".depth AS depth, "DT_node_data_29".parent_id AS parent_id, "DT_node_data_29"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_29" LEFT OUTER JOIN "DT_node_data_29" ON "DT_node_lookup_29".node_id_2 = "DT_node_data_29".node_id),
# "GB_Tree_9_2" AS
# (SELECT "DT_Output_29"."KEY" AS "KEY", 0.0 AS "Score_0", 0.0 AS "Score_1", "DT_Output_29"."Estimator" AS "Score_2"
# FROM "DT_Output_29"),
# "DT_node_lookup_30" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7213706970214844) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.1961124837398529) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.616089940071106) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_30" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.011080333024402362 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.22600841522216797 AS threshold, 99 AS count, 1 AS depth, 0 AS parent_id, -0.1207295502307674 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.7213706970214844 AS threshold, 19 AS count, 2 AS depth, 1 AS parent_id, -0.145125182160616 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 11 AS count, 3 AS depth, 2 AS parent_id, -0.7646383337061051 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, 2 AS parent_id, -0.8141743500256352 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.1961124837398529 AS threshold, 80 AS count, 2 AS depth, 1 AS parent_id, -0.11493558764742831 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 72 AS count, 3 AS depth, 5 AS parent_id, -0.7548616187296903 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, 5 AS parent_id, -0.7731255667354598 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, 0 AS parent_id, 0.20176814743501217 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, -1.616089940071106 AS threshold, 50 AS count, 2 AS depth, 8 AS parent_id, 0.20831774849415655 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, 9 AS parent_id, 1.0835972562657727 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, 9 AS parent_id, 0.8382889199882907 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, 8 AS parent_id, -0.7625251571850177 AS "Estimator") AS "Values"),
# "DT_Output_30" AS
# (SELECT "DT_node_lookup_30"."KEY" AS "KEY", "DT_node_lookup_30".node_id_2 AS node_id_2, "DT_node_data_30".node_id AS node_id, "DT_node_data_30".feature AS feature, "DT_node_data_30".threshold AS threshold, "DT_node_data_30".count AS count, "DT_node_data_30".depth AS depth, "DT_node_data_30".parent_id AS parent_id, "DT_node_data_30"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_30" LEFT OUTER JOIN "DT_node_data_30" ON "DT_node_lookup_30".node_id_2 = "DT_node_data_30".node_id),
# "GB_Tree_10_0" AS
# (SELECT "DT_Output_30"."KEY" AS "KEY", "DT_Output_30"."Estimator" AS "Score_0", 0.0 AS "Score_1", 0.0 AS "Score_2"
# FROM "DT_Output_30"),
# "DT_node_lookup_31" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.21414503455162048) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.031633276492357254) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= -0.13445144891738892) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_31" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.005163070340700502 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 99 AS count, 1 AS depth, 0 AS parent_id, 0.05482490559500559 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, -0.21414503455162048 AS threshold, 53 AS count, 2 AS depth, 1 AS parent_id, 0.1497185965388402 AS "

# %% [markdown]
# ## Execute the SQL Code

# %%
# save the dataset in a database table

#engine = sa.create_engine('sqlite://' , echo=False)
engine = sa.create_engine("postgresql://db:db@localhost/db?port=5432", echo=False)
conn = engine.connect()

lTable = pd.DataFrame(X);
lTable.columns = ['Feature_0', 'Feature_1', 'Feature_2', 'Feature_3']
lTable['KEY'] = range(lTable.shape[0])
lTable.to_sql("INPUT_DATA" , conn,   if_exists='replace', index=False)

# %%
sql_output = pd.read_sql(lSQL , conn);
sql_output = sql_output.sort_values(by='KEY').reset_index(drop=True)
conn.close()

# %%
sql_output.sample(12, random_state=1960)
# Out:
#      KEY   Score_0   Score_1   Score_2   Proba_0   Proba_1   Proba_2  \
# 114  114 -5.847875 -2.386117  5.636359  0.000010  0.000328  0.999662
# 74    74 -5.950055  4.889877 -4.534668  0.000020  0.999900  0.000081
# 9      9  7.360124 -0.304112 -3.975247  0.999519  0.000469  0.000012
# 88    88 -5.896603  3.123422 -3.313516  0.000121  0.998281  0.001599
# 25    25  7.360124 -0.864932 -3.975247  0.999720  0.000268  0.000012
# 5      5  7.300874 -1.060958 -4.427017  0.999758  0.000234  0.000008
# 48    48  7.300874 -0.833077 -4.669324  0.999700  0.000293  0.000006
# 117  117 -5.883320 -1.628652  4.583826  0.000028  0.002000  0.997971
# 83    83 -5.865133  2.933801 -1.269759  0.000149  0.985131  0.014720
# 105  105 -5.873761 -3.348226  3.728754  0.000067  0.000844  0.999089
# 27    27  7.300874 -1.025818 -4.038590  0.999746  0.000242  0.000012
# 64    64 -5.901247  2.564794 -3.927794  0.000210  0.998278  0.001512
#
#      LogProba_0  LogProba_1  LogProba_2  Decision  DecisionProba
# 114  -11.484572   -8.022815   -0.000338         2       0.999662
# 74   -10.840033   -0.000100   -9.424646         1       0.999900
# 9     -0.000481   -7.664718  -11.335853         0       0.999519
# 88    -9.021746   -0.001721   -6.438659         1       0.998281
# 25    -0.000280   -8.225336  -11.335651         0       0.999720
# 5     -0.000242   -8.362074  -11.728132         0       0.999758
# 48    -0.000300   -8.134251  -11.970497         0       0.999700
# 117  -10.469176   -6.214509   -0.002031         2       0.997971
# 83    -8.813914   -0.014980   -4.218540         1       0.985131
# 105   -9.603427   -7.077891   -0.000911         2       0.999089
# 27    -0.000254   -8.326946  -11.339718         0       0.999746
# 64    -8.467765   -0.001724   -6.494312         1       0.998278

# %%
sql_output.Decision.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Decision, dtype: int64

# %% [markdown]
# ## Scikit-learn Prediction

# %%
skl_outputs = pd.DataFrame()
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['KEY']);
skl_output_score = pd.DataFrame(columns=['Score_0', 'Score_1', 'Score_2']);
skl_output_proba = pd.DataFrame(clf.predict_proba(X), columns=['Proba_0', 'Proba_1', 'Proba_2'])
skl_output_log_proba = pd.DataFrame(clf.predict_log_proba(X), columns=['LogProba_0', 'LogProba_1', 'LogProba_2'])
skl_output_decision = pd.DataFrame(clf.predict(X), columns=['Decision'])
skl_output = pd.concat([skl_output_key, skl_output_score, skl_output_proba, skl_output_log_proba, skl_output_decision] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
#      KEY Score_0 Score_1 Score_2   Proba_0   Proba_1   Proba_2  LogProba_0  \
# 114  114     NaN     NaN     NaN  0.000010  0.000328  0.999662  -11.484572
# 74    74     NaN     NaN     NaN  0.000020  0.999900  0.000081  -10.840033
# 9      9     NaN     NaN     NaN  0.999519  0.000469  0.000012   -0.000481
# 88    88     NaN     NaN     NaN  0.000121  0.998281  0.001599   -9.021746
# 25    25     NaN     NaN     NaN  0.999720  0.000268  0.000012   -0.000280
# 5      5     NaN     NaN     NaN  0.999758  0.000234  0.000008   -0.000242
# 48    48     NaN     NaN     NaN  0.999700  0.000293  0.000006   -0.000300
# 117  117     NaN     NaN     NaN  0.000028  0.002000  0.997971  -10.469176
# 83    83     NaN     NaN     NaN  0.000149  0.985131  0.014720   -8.813914
# 105  105     NaN     NaN     NaN  0.000067  0.000844  0.999089   -9.603427
# 27    27     NaN     NaN     NaN  0.999746  0.000242  0.000012   -0.000254
# 64    64     NaN     NaN     NaN  0.000210  0.998278  0.001512   -8.467765
#
#      LogProba_1  LogProba_2  Decision
# 114   -8.022815   -0.000338         2
# 74    -0.000100   -9.424646         1
# 9     -7.664718  -11.335853         0
# 88    -0.001721   -6.438659         1
# 25    -8.225336  -11.335651         0
# 5     -8.362074  -11.728132         0
# 48    -8.134251  -11.970497         0
# 117   -6.214509   -0.002031         2
# 83    -0.014980   -4.218540         1
# 105   -7.077891   -0.000911         2
# 27    -8.326946  -11.339718         0
# 64    -0.001724   -6.494312         1

# %% [markdown]
# ## Comparing the SQL and Scikit-learn Predictions

# %%
sql_skl_join = skl_output.join(sql_output , how='left', on='KEY', lsuffix='_skl', rsuffix='_sql')

# %%
sql_skl_join.sample(12, random_state=1960)
# Out:
#      KEY_skl Score_0_skl Score_1_skl Score_2_skl  Proba_0_skl  Proba_1_skl  \
# 114      114         NaN         NaN         NaN     0.000010     0.000328
# 74        74         NaN         NaN         NaN     0.000020     0.999900
# 9          9         NaN         NaN         NaN     0.999519     0.000469
# 88        88         NaN         NaN         NaN     0.000121     0.998281
# 25        25         NaN         NaN         NaN     0.999720     0.000268
# 5          5         NaN         NaN         NaN     0.999758     0.000234
# 48        48         NaN         NaN         NaN     0.999700     0.000293
# 117      117         NaN         NaN         NaN     0.000028     0.002000
# 83        83         NaN         NaN         NaN     0.000149     0.985131
# 105      105         NaN         NaN         NaN     0.000067     0.000844
# 27        27         NaN         NaN         NaN     0.999746     0.000242
# 64        64         NaN         NaN         NaN     0.000210     0.998278
#
#      Proba_2_skl  LogProba_0_skl  LogProba_1_skl  LogProba_2_skl  \
# 114     0.999662      -11.484572       -8.022815       -0.000338
# 74      0.000081      -10.840033       -0.000100       -9.424646
# 9       0.000012       -0.000481       -7.664718      -11.335853
# 88      0.001599       -9.021746       -0.001721       -6.438659
# 25      0.000012       -0.000280       -8.225336      -11.335651
# 5       0.000008       -0.000242       -8.362074      -11.728132
# 48      0.000006       -0.000300       -8.134251      -11.970497
# 117     0.997971      -10.469176       -6.214509       -0.002031
# 83      0.014720       -8.813914       -0.014980       -4.218540
# 105     0.999089       -9.603427       -7.077891       -0.000911
# 27      0.000012       -0.000254       -8.326946      -11.339718
# 64      0.001512       -8.467765       -0.001724       -6.494312
#
#          ...        Score_1_sql  Score_2_sql  Proba_0_sql  Proba_1_sql  \
# 114      ...          -2.386117     5.636359     0.000010     0.000328
# 74       ...           4.889877    -4.534668     0.000020     0.999900
# 9        ...          -0.304112    -3.975247     0.999519     0.000469
# 88       ...           3.123422    -3.313516     0.000121     0.998281
# 25       ...          -0.864932    -3.975247     0.999720     0.000268
# 5        ...          -1.060958    -4.427017     0.999758     0.000234
# 48       ...          -0.833077    -4.669324     0.999700     0.000293
# 117      ...          -1.628652     4.583826     0.000028     0.002000
# 83       ...           2.933801    -1.269759     0.000149     0.985131
# 105      ...          -3.348226     3.728754     0.000067     0.000844
# 27       ...          -1.025818    -4.038590     0.999746     0.000242
# 64       ...           2.564794    -3.927794     0.000210     0.998278
#
#      Proba_2_sql  LogProba_0_sql  LogProba_1_sql  LogProba_2_sql  \
# 114     0.999662      -11.484572       -8.022815       -0.000338
# 74      0.000081      -10.840033       -0.000100       -9.424646
# 9       0.000012       -0.000481       -7.664718      -11.335853
# 88      0.001599       -9.021746       -0.001721       -6.438659
# 25      0.000012       -0.000280       -8.225336      -11.335651
# 5       0.000008       -0.000242       -8.362074      -11.728132
# 48      0.000006       -0.000300       -8.134251      -11.970497
# 117     0.997971      -10.469176       -6.214509       -0.002031
# 83      0.014720       -8.813914       -0.014980       -4.218540
# 105     0.999089       -9.603427       -7.077891       -0.000911
# 27      0.000012       -0.000254       -8.326946      -11.339718
# 64      0.001512       -8.467765       -0.001724       -6.494312
#
#      Decision_sql  DecisionProba
# 114             2       0.999662
# 74              1       0.999900
# 9               0       0.999519
# 88              1       0.998281
# 25              0       0.999720
# 5               0       0.999758
# 48              0       0.999700
# 117             2       0.997971
# 83              1       0.985131
# 105             2       0.999089
# 27              0       0.999746
# 64              1       0.998278
#
# [12 rows x 23 columns]

# %%
condition = (sql_skl_join.Decision_sql != sql_skl_join.Decision_skl)
sql_skl_join[condition]
# Out:
# Empty DataFrame
# Columns: [KEY_skl, Score_0_skl, Score_1_skl, Score_2_skl, Proba_0_skl, Proba_1_skl, Proba_2_skl, LogProba_0_skl, LogProba_1_skl, LogProba_2_skl, Decision_skl, KEY_sql, Score_0_sql, Score_1_sql, Score_2_sql, Proba_0_sql, Proba_1_sql, Proba_2_sql, LogProba_0_sql, LogProba_1_sql, LogProba_2_sql, Decision_sql, DecisionProba]
# Index: []
#
# [0 rows x 23 columns]
