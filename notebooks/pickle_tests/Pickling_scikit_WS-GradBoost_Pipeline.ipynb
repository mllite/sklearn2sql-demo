# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa
import pickle, json, requests, base64

# %% [markdown]
# ## Build a scikit-learn model

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data  
Y = iris.target
# print(iris.DESCR)

# %%
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.decomposition import PCA
from sklearn.preprocessing import Imputer, StandardScaler, MinMaxScaler
from sklearn.preprocessing import RobustScaler, MaxAbsScaler

from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier

imputers = [('imputer', Imputer())]
scalers =  [('std_scaler', StandardScaler()), ('minmax_scaler', MinMaxScaler()),
            ('maxabs_scaler', MaxAbsScaler()), ('robust_scaler', RobustScaler())];
pcas = [('pca_4comps', PCA(n_components = 4))]
estimators = [('booster', GradientBoostingClassifier())]
random_state = np.random.RandomState(0)
clf = Pipeline(imputers + scalers + pcas + estimators)

clf.fit(X, Y)
# Out:
# Pipeline(steps=[('imputer', Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0)), ('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('minmax_scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('maxabs_scaler', MaxAbsScaler(copy=True)), ('robust_scaler', ...=100, presort='auto', random_state=None,
#               subsample=1.0, verbose=0, warm_start=False))])

# %%
#clf.__dict__

# %% [markdown]
# ## Generate SQL Code from the Model

# %%
def test_ws_sql_gen(pickle_data):
    WS_URL="http://192.168.88.88:1888/model" # "https://sklearn2sql.herokuapp.com/"
    b64_data = base64.b64encode(pickle_data)
    data={"Name":"model1", "PickleData":b64_data , "SQLDialect":"postgresql"}
    r = requests.post(WS_URL, json=data)
    content = r.json()
    # print(content)
    lSQL = content["model"]["SQLGenrationResult"][0]["SQL"]
    return lSQL;

# %%
pickle_data = pickle.dumps(clf)
lSQL = test_ws_sql_gen(pickle_data)
print(lSQL[0:120000])
# Out:
# WITH "ADS_imp_1_OUT" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_0" IS NULL) THEN 5.84333333333 ELSE "ADS"."Feature_0" END AS imputer_output_2, CASE WHEN ("ADS"."Feature_1" IS NULL) THEN 3.054 ELSE "ADS"."Feature_1" END AS imputer_output_3, CASE WHEN ("ADS"."Feature_2" IS NULL) THEN 3.75866666667 ELSE "ADS"."Feature_2" END AS imputer_output_4, CASE WHEN ("ADS"."Feature_3" IS NULL) THEN 1.19866666667 ELSE "ADS"."Feature_3" END AS imputer_output_5
# FROM "INPUT_DATA" AS "ADS"),
# "ADS_std_2_OUT" AS
# (SELECT "ADS_imp_1_OUT"."KEY" AS "KEY", (CAST("ADS_imp_1_OUT".imputer_output_2 AS FLOAT) - 5.84333333333) / 0.825301291785 AS std_scaler_output_2, (CAST("ADS_imp_1_OUT".imputer_output_3 AS FLOAT) - 3.054) / 0.432146580071 AS std_scaler_output_3, (CAST("ADS_imp_1_OUT".imputer_output_4 AS FLOAT) - 3.75866666667) / 1.75852918341 AS std_scaler_output_4, (CAST("ADS_imp_1_OUT".imputer_output_5 AS FLOAT) - 1.19866666667) / 0.760612618588 AS std_scaler_output_5
# FROM "ADS_imp_1_OUT"),
# "ADS_min_3_OUT" AS
# (SELECT "ADS_std_2_OUT"."KEY" AS "KEY", "ADS_std_2_OUT".std_scaler_output_2 * 0.229250358829 + 0.428703703704 AS minmax_scaler_output_2, "ADS_std_2_OUT".std_scaler_output_3 * 0.180061075029 + 0.439166666667 AS minmax_scaler_output_3, "ADS_std_2_OUT".std_scaler_output_4 * 0.298055793798 + 0.467570621469 AS minmax_scaler_output_4, "ADS_std_2_OUT".std_scaler_output_5 * 0.316921924412 + 0.457777777778 AS minmax_scaler_output_5
# FROM "ADS_std_2_OUT"),
# "ADS_max_4_OUT" AS
# (SELECT "ADS_min_3_OUT"."KEY" AS "KEY", CAST("ADS_min_3_OUT".minmax_scaler_output_2 AS FLOAT) / 1.0 AS maxabs_scaler_output_2, CAST("ADS_min_3_OUT".minmax_scaler_output_3 AS FLOAT) / 1.0 AS maxabs_scaler_output_3, CAST("ADS_min_3_OUT".minmax_scaler_output_4 AS FLOAT) / 1.0 AS maxabs_scaler_output_4, CAST("ADS_min_3_OUT".minmax_scaler_output_5 AS FLOAT) / 1.0 AS maxabs_scaler_output_5
# FROM "ADS_min_3_OUT"),
# "ADS_rob_5_OUT" AS
# (SELECT "ADS_max_4_OUT"."KEY" AS "KEY", (CAST("ADS_max_4_OUT".maxabs_scaler_output_2 AS FLOAT) - 0.416666666667) / 0.361111111111 AS robust_scaler_output_2, (CAST("ADS_max_4_OUT".maxabs_scaler_output_3 AS FLOAT) - 0.416666666667) / 0.208333333333 AS robust_scaler_output_3, (CAST("ADS_max_4_OUT".maxabs_scaler_output_4 AS FLOAT) - 0.567796610169) / 0.593220338983 AS robust_scaler_output_4, (CAST("ADS_max_4_OUT".maxabs_scaler_output_5 AS FLOAT) - 0.5) / 0.625 AS robust_scaler_output_5
# FROM "ADS_max_4_OUT"),
# "CenteredDataForPCA" AS
# (SELECT "ADS_rob_5_OUT"."KEY" AS "KEY", "ADS_rob_5_OUT".robust_scaler_output_2 - 0.0333333333333 AS robust_scaler_output_2, "ADS_rob_5_OUT".robust_scaler_output_3 - 0.108 AS robust_scaler_output_3, "ADS_rob_5_OUT".robust_scaler_output_4 - -0.168952380952 AS robust_scaler_output_4, "ADS_rob_5_OUT".robust_scaler_output_5 - -0.0675555555556 AS robust_scaler_output_5
# FROM "ADS_rob_5_OUT"),
# "ADS_pca_6_OUT" AS
# (SELECT "CenteredDataForPCA"."KEY" AS "KEY", "CenteredDataForPCA".robust_scaler_output_2 * -0.447657317765 + "CenteredDataForPCA".robust_scaler_output_3 * 0.64147212658 + "CenteredDataForPCA".robust_scaler_output_4 * -0.450983672283 + "CenteredDataForPCA".robust_scaler_output_5 * -0.429802470918 AS pca_4comps_output_2, "CenteredDataForPCA".robust_scaler_output_2 * 0.548644834048 + "CenteredDataForPCA".robust_scaler_output_3 * 0.746908939088 + "CenteredDataForPCA".robust_scaler_output_4 * 0.254203875701 + "CenteredDataForPCA".robust_scaler_output_5 * 0.276579594985 AS pca_4comps_output_3, "CenteredDataForPCA".robust_scaler_output_2 * -0.676170469726 + "CenteredDataForPCA".robust_scaler_output_3 * 0.159989073346 + "CenteredDataForPCA".robust_scaler_output_4 * 0.259558177741 + "CenteredDataForPCA".robust_scaler_output_5 * 0.670691094803 AS pca_4comps_output_4, "CenteredDataForPCA".robust_scaler_output_2 * -0.203433693853 + "CenteredDataForPCA".robust_scaler_output_3 * 0.0710214329801 + "CenteredDataForPCA".robust_scaler_output_4 * 0.815244545692 + "CenteredDataForPCA".robust_scaler_output_5 * -0.537537923297 AS pca_4comps_output_5
# FROM "CenteredDataForPCA"),
# "DT_node_lookup" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN 1 ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN 3 ELSE 4 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 3.515706244646329e-16 AS "Estimator" UNION ALL SELECT 1 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 99 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -1.0 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.6470588235294121 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 50 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 2.0 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9999999999999999 AS "Estimator") AS "Values"),
# "DT_Output" AS
# (SELECT "DT_node_lookup"."KEY" AS "KEY", "DT_node_lookup".node_id_2 AS node_id_2, "DT_node_data".node_id AS node_id, "DT_node_data".feature AS feature, "DT_node_data".threshold AS threshold, "DT_node_data".count AS count, "DT_node_data".depth AS depth, "DT_node_data".parent_id AS parent_id, "DT_node_data"."Estimator" AS "Estimator"
# FROM "DT_node_lookup" LEFT OUTER JOIN "DT_node_data" ON "DT_node_lookup".node_id_2 = "DT_node_data".node_id),
# "RF_Tree_0_0" AS
# (SELECT "DT_Output"."KEY" AS join_key_0_0, "DT_Output"."Estimator" AS "Estimator_0_0"
# FROM "DT_Output"),
# "DT_node_lookup_1" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.6178238987922668) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.1961124837398529) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_1" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.00035651168661645266 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 101 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.1511311054672251 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.6178238987922668 AS threshold, 54 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3785953500395856 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 26 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3463677023519576 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 28 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.838051613219892 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.1961124837398529 AS threshold, 47 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.11021079255208327 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 43 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.5358975011316298 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 4 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.9365582786906392 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9667773351250147 AS "Estimator") AS "Values"),
# "DT_Output_1" AS
# (SELECT "DT_node_lookup_1"."KEY" AS "KEY", "DT_node_lookup_1".node_id_2 AS node_id_2, "DT_node_data_1".node_id AS node_id, "DT_node_data_1".feature AS feature, "DT_node_data_1".threshold AS threshold, "DT_node_data_1".count AS count, "DT_node_data_1".depth AS depth, "DT_node_data_1".parent_id AS parent_id, "DT_node_data_1"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_1" LEFT OUTER JOIN "DT_node_data_1" ON "DT_node_lookup_1".node_id_2 = "DT_node_data_1".node_id),
# "RF_Tree_0_1" AS
# (SELECT "DT_Output_1"."KEY" AS join_key_0_1, "DT_Output_1"."Estimator" AS "Estimator_0_1"
# FROM "DT_Output_1"),
# "DT_node_lookup_2" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.4558808207511902) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.17407992482185364) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1462516337633133) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.1800115704536438) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.9675517082214355) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.18666619062423706) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_2" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0010562774898447503 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.4558808207511902 AS threshold, 44 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.42738882084746144 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.17407992482185364 AS threshold, 9 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.1179044582108525 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.6390013081196498 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.960054018161165 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, 0.1462516337633133 AS threshold, 35 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.5676070926053137 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 13 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.2745888771640264 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 22 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.9017721921279367 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.1800115704536438 AS threshold, 106 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.1759119480548268 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, 1.9675517082214355 AS threshold, 88 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.2787992602904113 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 86 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.915279481566999 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.9017721921279374 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_2' AS feature, -0.18666619062423706 AS threshold, 18 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3270926895413655 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 13 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.6967488725236313 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 5 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9817477403845429 AS "Estimator") AS "Values"),
# "DT_Output_2" AS
# (SELECT "DT_node_lookup_2"."KEY" AS "KEY", "DT_node_lookup_2".node_id_2 AS node_id_2, "DT_node_data_2".node_id AS node_id, "DT_node_data_2".feature AS feature, "DT_node_data_2".threshold AS threshold, "DT_node_data_2".count AS count, "DT_node_data_2".depth AS depth, "DT_node_data_2".parent_id AS parent_id, "DT_node_data_2"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_2" LEFT OUTER JOIN "DT_node_data_2" ON "DT_node_lookup_2".node_id_2 = "DT_node_data_2".node_id),
# "RF_Tree_0_2" AS
# (SELECT "DT_Output_2"."KEY" AS join_key_0_2, "DT_Output_2"."Estimator" AS "Estimator_0_2"
# FROM "DT_Output_2"),
# "RF_Join_CTE_0" AS
# (SELECT "RF_Tree_0_0".join_key_0_0 AS join_key_0_0, "RF_Tree_0_0"."Estimator_0_0" AS "Estimator_0_0", "RF_Tree_0_1".join_key_0_1 AS join_key_0_1, "RF_Tree_0_1"."Estimator_0_1" AS "Estimator_0_1", "RF_Tree_0_2".join_key_0_2 AS join_key_0_2, "RF_Tree_0_2"."Estimator_0_2" AS "Estimator_0_2"
# FROM "RF_Tree_0_0" LEFT OUTER JOIN "RF_Tree_0_1" ON "RF_Tree_0_0".join_key_0_0 = "RF_Tree_0_1".join_key_0_1 LEFT OUTER JOIN "RF_Tree_0_2" ON "RF_Tree_0_2".join_key_0_2 = "RF_Tree_0_1".join_key_0_1),
# "DT_node_lookup_3" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.11648331582546234) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.04128652811050415) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.8562636375427246) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= -0.13445144891738892) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_3" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.0010728484615650613 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.11648331582546234 AS threshold, 99 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.30120537754117643 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.04128652811050415 AS threshold, 31 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.3070892095612294 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 22 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9690708011845021 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 9 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9473621014270752 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, -0.8562636375427246 AS threshold, 68 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.29852304235556437 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 9 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9601797595520577 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 59 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9491643130185838 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.5815373550459159 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_5' AS feature, -0.13445144891738892 AS threshold, 50 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.5991504856942133 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.8207044835470025 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.6602023777818735 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9511840603143531 AS "Estimator") AS "Values"),
# "DT_Output_3" AS
# (SELECT "DT_node_lookup_3"."KEY" AS "KEY", "DT_node_lookup_3".node_id_2 AS node_id_2, "DT_node_data_3".node_id AS node_id, "DT_node_data_3".feature AS feature, "DT_node_data_3".threshold AS threshold, "DT_node_data_3".count AS count, "DT_node_data_3".depth AS depth, "DT_node_data_3".parent_id AS parent_id, "DT_node_data_3"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_3" LEFT OUTER JOIN "DT_node_data_3" ON "DT_node_lookup_3".node_id_2 = "DT_node_data_3".node_id),
# "RF_Tree_1_0" AS
# (SELECT "DT_Output_3"."KEY" AS join_key_1_0, "DT_Output_3"."Estimator" AS "Estimator_1_0"
# FROM "DT_Output_3"),
# "DT_node_lookup_4" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.6178238987922668) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.1961124837398529) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_4" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0008030872863557866 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 101 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.13620443436959873 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.6178238987922668 AS threshold, 54 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.34121042412135183 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 26 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3112684702942728 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 28 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.5471032121381718 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.1961124837398529 AS threshold, 47 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.09933436236645829 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 43 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.4957924822553667 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 4 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.6182498426335121 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.923731428008898 AS "Estimator") AS "Values"),
# "DT_Output_4" AS
# (SELECT "DT_node_lookup_4"."KEY" AS "KEY", "DT_node_lookup_4".node_id_2 AS node_id_2, "DT_node_data_4".node_id AS node_id, "DT_node_data_4".feature AS feature, "DT_node_data_4".threshold AS threshold, "DT_node_data_4".count AS count, "DT_node_data_4".depth AS depth, "DT_node_data_4".parent_id AS parent_id, "DT_node_data_4"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_4" LEFT OUTER JOIN "DT_node_data_4" ON "DT_node_lookup_4".node_id_2 = "DT_node_data_4".node_id),
# "RF_Tree_1_1" AS
# (SELECT "DT_Output_4"."KEY" AS join_key_1_1, "DT_Output_4"."Estimator" AS "Estimator_1_1"
# FROM "DT_Output_4"),
# "DT_node_lookup_5" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.4558808207511902) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.02152065373957157) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.40767401456832886) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.1800115704536438) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.9675517082214355) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.18666619062423706) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_5" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0014969528709503476 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.4558808207511902 AS threshold, 44 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3865176024037699 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.02152065373957157 AS threshold, 9 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.1161779118332359 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.6382565466110102 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 2.0092696818125098 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.40767401456832886 AS threshold, 35 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.5157821632075715 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.2969225649451229 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 33 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.5051920262503187 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.1800115704536438 AS threshold, 106 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.15832293938795605 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, 1.9675517082214355 AS threshold, 88 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.2517434186576469 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 86 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8719364586745733 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.6174747528013367 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_2' AS feature, -0.18666619062423706 AS threshold, 18 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.2983994037083092 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 13 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.4577451546188607 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 5 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9359804801714388 AS "Estimator") AS "Values"),
# "DT_Output_5" AS
# (SELECT "DT_node_lookup_5"."KEY" AS "KEY", "DT_node_lookup_5".node_id_2 AS node_id_2, "DT_node_data_5".node_id AS node_id, "DT_node_data_5".feature AS feature, "DT_node_data_5".threshold AS threshold, "DT_node_data_5".count AS count, "DT_node_data_5".depth AS depth, "DT_node_data_5".parent_id AS parent_id, "DT_node_data_5"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_5" LEFT OUTER JOIN "DT_node_data_5" ON "DT_node_lookup_5".node_id_2 = "DT_node_data_5".node_id),
# "RF_Tree_1_2" AS
# (SELECT "DT_Output_5"."KEY" AS join_key_1_2, "DT_Output_5"."Estimator" AS "Estimator_1_2"
# FROM "DT_Output_5"),
# "RF_Join_CTE_1" AS
# (SELECT "RF_Tree_1_0".join_key_1_0 AS join_key_1_0, "RF_Tree_1_0"."Estimator_1_0" AS "Estimator_1_0", "RF_Tree_1_1".join_key_1_1 AS join_key_1_1, "RF_Tree_1_1"."Estimator_1_1" AS "Estimator_1_1", "RF_Tree_1_2".join_key_1_2 AS join_key_1_2, "RF_Tree_1_2"."Estimator_1_2" AS "Estimator_1_2"
# FROM "RF_Tree_1_0" LEFT OUTER JOIN "RF_Tree_1_1" ON "RF_Tree_1_0".join_key_1_0 = "RF_Tree_1_1".join_key_1_1 LEFT OUTER JOIN "RF_Tree_1_2" ON "RF_Tree_1_2".join_key_1_2 = "RF_Tree_1_1".join_key_1_1),
# "DT_node_lookup_6" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7213706970214844) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.108229398727417) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= -0.13445144891738892) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_6" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.0024227902397207283 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.22600841522216797 AS threshold, 99 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.272227905337818 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.7213706970214844 AS threshold, 19 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.2876945070485741 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 11 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9189267989437914 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.964508252068605 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, -1.108229398727417 AS threshold, 80 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.2685545874315135 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9337717166788663 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 73 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9103685505774246 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.5213165508330563 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_5' AS feature, -0.13445144891738892 AS threshold, 50 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.53709384752464 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.685424500438177 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.4359129271650908 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9101851383137356 AS "Estimator") AS "Values"),
# "DT_Output_6" AS
# (SELECT "DT_node_lookup_6"."KEY" AS "KEY", "DT_node_lookup_6".node_id_2 AS node_id_2, "DT_node_data_6".node_id AS node_id, "DT_node_data_6".feature AS feature, "DT_node_data_6".threshold AS threshold, "DT_node_data_6".count AS count, "DT_node_data_6".depth AS depth, "DT_node_data_6".parent_id AS parent_id, "DT_node_data_6"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_6" LEFT OUTER JOIN "DT_node_data_6" ON "DT_node_lookup_6".node_id_2 = "DT_node_data_6".node_id),
# "RF_Tree_2_0" AS
# (SELECT "DT_Output_6"."KEY" AS join_key_2_0, "DT_Output_6"."Estimator" AS "Estimator_2_0"
# FROM "DT_Output_6"),
# "DT_node_lookup_7" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.7124893665313721) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.3935815691947937) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_7" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0014535719119182949 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.7124893665313721 AS threshold, 101 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.12280720071118835 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 79 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.22865314796279845 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 33 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.10671862724350643 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 46 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.1541063535875702 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.3935815691947937 AS threshold, 22 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.25727597351050224 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.4873243328780694 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 20 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9523786247610652 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8873313889898442 AS "Estimator") AS "Values"),
# "DT_Output_7" AS
# (SELECT "DT_node_lookup_7"."KEY" AS "KEY", "DT_node_lookup_7".node_id_2 AS node_id_2, "DT_node_data_7".node_id AS node_id, "DT_node_data_7".feature AS feature, "DT_node_data_7".threshold AS threshold, "DT_node_data_7".count AS count, "DT_node_data_7".depth AS depth, "DT_node_data_7".parent_id AS parent_id, "DT_node_data_7"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_7" LEFT OUTER JOIN "DT_node_data_7" ON "DT_node_lookup_7".node_id_2 = "DT_node_data_7".node_id),
# "RF_Tree_2_1" AS
# (SELECT "DT_Output_7"."KEY" AS join_key_2_1, "DT_Output_7"."Estimator" AS "Estimator_2_1"
# FROM "DT_Output_7"),
# "DT_node_lookup_8" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.4757063388824463) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.6644308567047119) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.031499482691287994) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.12673455476760864) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.7185304164886475) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.47118985652923584) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.028232239186763763) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_8" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.4757063388824463 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.002043114224690439 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, -0.6644308567047119 AS threshold, 63 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.26430307596522606 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.031499482691287994 AS threshold, 14 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.17331802161632012 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 11 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9632654441100066 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 3 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.9234405667338121 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.12673455476760864 AS threshold, 49 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3893376752742393 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 17 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3758328993062187 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 32 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.4275919288302388 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_3' AS feature, 1.7185304164886475 AS threshold, 87 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.18786927186328356 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_4' AS feature, 0.47118985652923584 AS threshold, 84 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.21342890335781184 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 82 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7916292701239551 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.4308178216356877 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_5' AS feature, 0.028232239186763763 AS threshold, 3 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.5278004099835097 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.4308178216356877 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 2 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.4025278839888469 AS "Estimator") AS "Values"),
# "DT_Output_8" AS
# (SELECT "DT_node_lookup_8"."KEY" AS "KEY", "DT_node_lookup_8".node_id_2 AS node_id_2, "DT_node_data_8".node_id AS node_id, "DT_node_data_8".feature AS feature, "DT_node_data_8".threshold AS threshold, "DT_node_data_8".count AS count, "DT_node_data_8".depth AS depth, "DT_node_data_8".parent_id AS parent_id, "DT_node_data_8"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_8" LEFT OUTER JOIN "DT_node_data_8" ON "DT_node_lookup_8".node_id_2 = "DT_node_data_8".node_id),
# "RF_Tree_2_2" AS
# (SELECT "DT_Output_8"."KEY" AS join_key_2_2, "DT_Output_8"."Estimator" AS "Estimator_2_2"
# FROM "DT_Output_8"),
# "RF_Join_CTE_2" AS
# (SELECT "RF_Tree_2_0".join_key_2_0 AS join_key_2_0, "RF_Tree_2_0"."Estimator_2_0" AS "Estimator_2_0", "RF_Tree_2_1".join_key_2_1 AS join_key_2_1, "RF_Tree_2_1"."Estimator_2_1" AS "Estimator_2_1", "RF_Tree_2_2".join_key_2_2 AS join_key_2_2, "RF_Tree_2_2"."Estimator_2_2" AS "Estimator_2_2"
# FROM "RF_Tree_2_0" LEFT OUTER JOIN "RF_Tree_2_1" ON "RF_Tree_2_0".join_key_2_0 = "RF_Tree_2_1".join_key_2_1 LEFT OUTER JOIN "RF_Tree_2_2" ON "RF_Tree_2_2".join_key_2_2 = "RF_Tree_2_1".join_key_2_1),
# "DT_node_lookup_9" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.037814125418663025) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.108229398727417) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -1.616089940071106) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_9" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.003769054554793995 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.22600841522216797 AS threshold, 99 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.24612354102449574 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_5' AS feature, 0.037814125418663025 AS threshold, 19 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.26585237230781955 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 14 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9203113343071064 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 5 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8824232246288954 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, -1.108229398727417 AS threshold, 80 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.24143794359470622 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9109813615664525 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 73 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8772928344854053 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.4666837721216856 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_3' AS feature, -1.616089940071106 AS threshold, 50 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.48083992170898776 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.5689115457594327 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.2793862934525553 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8784918873207088 AS "Estimator") AS "Values"),
# "DT_Output_9" AS
# (SELECT "DT_node_lookup_9"."KEY" AS "KEY", "DT_node_lookup_9".node_id_2 AS node_id_2, "DT_node_data_9".node_id AS node_id, "DT_node_data_9".feature AS feature, "DT_node_data_9".threshold AS threshold, "DT_node_data_9".count AS count, "DT_node_data_9".depth AS depth, "DT_node_data_9".parent_id AS parent_id, "DT_node_data_9"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_9" LEFT OUTER JOIN "DT_node_data_9" ON "DT_node_lookup_9".node_id_2 = "DT_node_data_9".node_id),
# "RF_Tree_3_0" AS
# (SELECT "DT_Output_9"."KEY" AS join_key_3_0, "DT_Output_9"."Estimator" AS "Estimator_3_0"
# FROM "DT_Output_9"),
# "DT_node_lookup_10" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.32208648324012756) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_10" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.002035786593092437 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 101 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.11041806414867417 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.32208648324012756 AS threshold, 54 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.2829840738990829 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 47 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.9877379559235023 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.64487139406816 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 47 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.08784926620285917 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 22 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.9240547756849841 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 25 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.23785671850187898 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8561986054662526 AS "Estimator") AS "Values"),
# "DT_Output_10" AS
# (SELECT "DT_node_lookup_10"."KEY" AS "KEY", "DT_node_lookup_10".node_id_2 AS node_id_2, "DT_node_data_10".node_id AS node_id, "DT_node_data_10".feature AS feature, "DT_node_data_10".threshold AS threshold, "DT_node_data_10".count AS count, "DT_node_data_10".depth AS depth, "DT_node_data_10".parent_id AS parent_id, "DT_node_data_10"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_10" LEFT OUTER JOIN "DT_node_data_10" ON "DT_node_lookup_10".node_id_2 = "DT_node_data_10".node_id),
# "RF_Tree_3_1" AS
# (SELECT "DT_Output_10"."KEY" AS join_key_3_1, "DT_Output_10"."Estimator" AS "Estimator_3_1"
# FROM "DT_Output_10"),
# "DT_node_lookup_11" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7043026685714722) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= -0.4558808207511902) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= 0.02152065373957157) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.856364369392395) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.1800115704536438) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 1.9675517082214355) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.18666619062423706) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_11" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# ...
# "RF_Tree_8_0" AS
# (SELECT "DT_Output_24"."KEY" AS join_key_8_0, "DT_Output_24"."Estimator" AS "Estimator_8_0"
# FROM "DT_Output_24"),
# "DT_node_lookup_25" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4824292063713074) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.32208648324012756) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN 6 ELSE 7 END END ELSE 8 END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_25" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.4824292063713074 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.004699833740029765 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 101 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.065676004192979 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.32208648324012756 AS threshold, 54 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.17445747398754585 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 47 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.6824927253646239 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.5410789571273904 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 47 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.05930696110290621 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 22 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8212739878188311 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 25 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.16954505312565066 AS "Estimator" UNION ALL SELECT 8 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7584254574899151 AS "Estimator") AS "Values"),
# "DT_Output_25" AS
# (SELECT "DT_node_lookup_25"."KEY" AS "KEY", "DT_node_lookup_25".node_id_2 AS node_id_2, "DT_node_data_25".node_id AS node_id, "DT_node_data_25".feature AS feature, "DT_node_data_25".threshold AS threshold, "DT_node_data_25".count AS count, "DT_node_data_25".depth AS depth, "DT_node_data_25".parent_id AS parent_id, "DT_node_data_25"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_25" LEFT OUTER JOIN "DT_node_data_25" ON "DT_node_lookup_25".node_id_2 = "DT_node_data_25".node_id),
# "RF_Tree_8_1" AS
# (SELECT "DT_Output_25"."KEY" AS join_key_8_1, "DT_Output_25"."Estimator" AS "Estimator_8_1"
# FROM "DT_Output_25"),
# "DT_node_lookup_26" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.4280029535293579) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.09884297847747803) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.679976761341095) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.7542281746864319) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.957033097743988) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN 10 ELSE 11 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.8192250728607178) THEN 13 ELSE 14 END END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_26" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, -0.4280029535293579 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.005381097208774181 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, 0.09884297847747803 AS threshold, 75 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.12387637342504286 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.679976761341095 AS threshold, 50 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.01978845802667193 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 31 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.4084368026613449 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 19 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8198710418213732 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_3' AS feature, 0.7542281746864319 AS threshold, 25 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3320522042217846 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 17 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.0619813056767895 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.929513788101346 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_3' AS feature, 0.957033097743988 AS threshold, 75 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.11311417900749458 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 68 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.1373412356239883 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 20 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8078272583341876 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 48 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7628703293045954 AS "Estimator" UNION ALL SELECT 12 AS node_id, 'pca_4comps_output_2' AS feature, 0.8192250728607178 AS threshold, 7 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.12223437098130187 AS "Estimator" UNION ALL SELECT 13 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 4 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.9653233436024569 AS "Estimator" UNION ALL SELECT 14 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 3 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7622921604445202 AS "Estimator") AS "Values"),
# "DT_Output_26" AS
# (SELECT "DT_node_lookup_26"."KEY" AS "KEY", "DT_node_lookup_26".node_id_2 AS node_id_2, "DT_node_data_26".node_id AS node_id, "DT_node_data_26".feature AS feature, "DT_node_data_26".threshold AS threshold, "DT_node_data_26".count AS count, "DT_node_data_26".depth AS depth, "DT_node_data_26".parent_id AS parent_id, "DT_node_data_26"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_26" LEFT OUTER JOIN "DT_node_data_26" ON "DT_node_lookup_26".node_id_2 = "DT_node_data_26".node_id),
# "RF_Tree_8_2" AS
# (SELECT "DT_Output_26"."KEY" AS join_key_8_2, "DT_Output_26"."Estimator" AS "Estimator_8_2"
# FROM "DT_Output_26"),
# "RF_Join_CTE_8" AS
# (SELECT "RF_Tree_8_0".join_key_8_0 AS join_key_8_0, "RF_Tree_8_0"."Estimator_8_0" AS "Estimator_8_0", "RF_Tree_8_1".join_key_8_1 AS join_key_8_1, "RF_Tree_8_1"."Estimator_8_1" AS "Estimator_8_1", "RF_Tree_8_2".join_key_8_2 AS join_key_8_2, "RF_Tree_8_2"."Estimator_8_2" AS "Estimator_8_2"
# FROM "RF_Tree_8_0" LEFT OUTER JOIN "RF_Tree_8_1" ON "RF_Tree_8_0".join_key_8_0 = "RF_Tree_8_1".join_key_8_1 LEFT OUTER JOIN "RF_Tree_8_2" ON "RF_Tree_8_2".join_key_8_2 = "RF_Tree_8_1".join_key_8_1),
# "DT_node_lookup_27" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.22600841522216797) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= -0.7213706970214844) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.16584187746047974) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_5 <= -0.13445144891738892) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_27" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.010384829820679453 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_4' AS feature, -0.22600841522216797 AS threshold, 99 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.13342622070701726 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_2' AS feature, -0.7213706970214844 AS threshold, 19 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.1602835983509274 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 11 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7788726775984852 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 8 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.8267221459213125 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, 0.16584187746047974 AS threshold, 80 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.1270475935165887 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 54 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7710854477927834 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 26 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.75717686353141 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.22846022307632932 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_5' AS feature, -0.13445144891738892 AS threshold, 50 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.2358894972350426 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.183870153131214 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.8678191797773985 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7779105922703125 AS "Estimator") AS "Values"),
# "DT_Output_27" AS
# (SELECT "DT_node_lookup_27"."KEY" AS "KEY", "DT_node_lookup_27".node_id_2 AS node_id_2, "DT_node_data_27".node_id AS node_id, "DT_node_data_27".feature AS feature, "DT_node_data_27".threshold AS threshold, "DT_node_data_27".count AS count, "DT_node_data_27".depth AS depth, "DT_node_data_27".parent_id AS parent_id, "DT_node_data_27"."Estimator" AS "Estimator"
# FROM "DT_node_lookup_27" LEFT OUTER JOIN "DT_node_data_27" ON "DT_node_lookup_27".node_id_2 = "DT_node_data_27".node_id),
# "RF_Tree_9_0" AS
# (SELECT "DT_Output_27"."KEY" AS join_key_9_0, "DT_Output_27"."Estimator" AS "Estimator_9_0"
# FROM "DT_Output_27"),
# "DT_node_lookup_28" AS
# (SELECT "ADS_pca_6_OUT"."KEY" AS "KEY", CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.005520036444067955) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_3 <= 0.1443094164133072) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.32208648324012756) THEN 3 ELSE 4 END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= -0.031633276492357254) THEN 6 ELSE 7 END END ELSE CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_4 <= 0.22216105461120605) THEN CASE WHEN ("ADS_pca_6_OUT".pca_4comps_output_2 <= 0.4274854063987732) THEN 10 ELSE 11 END ELSE 12 END END AS node_id_2
# FROM "ADS_pca_6_OUT"),
# "DT_node_data_28" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Estimator" AS "Estimator"
# FROM (SELECT 0 AS node_id, 'pca_4comps_output_2' AS feature, 0.005520036444067955 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.005009756158475318 AS "Estimator" UNION ALL SELECT 1 AS node_id, 'pca_4comps_output_3' AS feature, 0.1443094164133072 AS threshold, 99 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.06100734908009051 AS "Estimator" UNION ALL SELECT 2 AS node_id, 'pca_4comps_output_4' AS feature, 0.32208648324012756 AS threshold, 53 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.1668208541271483 AS "Estimator" UNION ALL SELECT 3 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 46 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.6727281858695137 AS "Estimator" UNION ALL SELECT 4 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 7 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.5016871954732511 AS "Estimator" UNION ALL SELECT 5 AS node_id, 'pca_4comps_output_4' AS feature, -0.031633276492357254 AS threshold, 46 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.0609082110828238 AS "Estimator" UNION ALL SELECT 6 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 19 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.25781119209439907 AS "Estimator" UNION ALL SELECT 7 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 27 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.6673766418157571 AS "Estimator" UNION ALL SELECT 8 AS node_id, 'pca_4comps_output_4' AS feature, 0.22216105461120605 AS threshold, 51 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.10369145363054239 AS "Estimator" UNION ALL SELECT 9 AS node_id, 'pca_4comps_output_2' AS feature, 0.4274854063987732 AS threshold, 50 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.11151714614185115 AS "Estimator" UNION ALL SELECT 10 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -1.0166247094338072 AS "Estimator" UNION ALL SELECT 11 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 49 AS count, 3 AS depth, CAST(NULL AS INTEGER) AS parent_id, -0.7463532423274125 AS "Estimator" UNION ALL SELECT 12 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 1 AS count, 2 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.9357948862973906 AS "Estimator") AS "Values"),
# "DT_Output_28" AS
# (

# %% [markdown]
# ## Execute the SQL Code

# %%
# save the dataset in a database table

#engine = sa.create_engine('sqlite://' , echo=False)
engine = sa.create_engine("postgresql://db:db@localhost/db?port=5432", echo=False)
conn = engine.connect()

lTable = pd.DataFrame(X);
lTable.columns = ['Feature_0', 'Feature_1', 'Feature_2', 'Feature_3']
lTable['KEY'] = range(lTable.shape[0])
lTable.to_sql("INPUT_DATA" , conn,   if_exists='replace', index=False)

# %%
sql_output = pd.read_sql(lSQL , conn);
sql_output = sql_output.sort_values(by='KEY').reset_index(drop=True)

# %%
sql_output.sample(12, random_state=1960)
# Out:
#      KEY   Score_0   Score_1   Score_2   Proba_0   Proba_1   Proba_2  \
# 114  114 -5.847731 -2.386357  5.636589  0.000010  0.000328  0.999662
# 74    74 -5.949027  4.889878 -4.534741  0.000020  0.999900  0.000081
# 9      9  7.360130 -0.304061 -3.975415  0.999519  0.000469  0.000012
# 88    88 -5.896455  3.123427 -3.313537  0.000121  0.998281  0.001599
# 25    25  7.360130 -0.864936 -3.975415  0.999720  0.000268  0.000012
# 5      5  7.300883 -1.060926 -4.427003  0.999758  0.000234  0.000008
# 48    48  7.300883 -0.833054 -4.669319  0.999700  0.000293  0.000006
# 117  117 -5.883144 -1.628549  4.584161  0.000028  0.002000  0.997972
# 83    83 -5.864954  2.933755 -1.269846  0.000149  0.985132  0.014720
# 105  105 -5.873120 -3.348146  3.728675  0.000068  0.000844  0.999089
# 27    27  7.300883 -1.025805 -4.038679  0.999746  0.000242  0.000012
# 64    64 -5.901081  2.564793 -3.927885  0.000210  0.998278  0.001512
#
#      LogProba_0  LogProba_1  LogProba_2  Decision
# 114  -11.484658   -8.023285   -0.000338         2
# 74   -10.839005   -0.000100   -9.424720         1
# 9     -0.000481   -7.664672  -11.336026         0
# 88    -9.021603   -0.001721   -6.438685         1
# 25    -0.000280   -8.225346  -11.335825         0
# 5     -0.000242   -8.362051  -11.728128         0
# 48    -0.000300   -8.134236  -11.970501         0
# 117  -10.469335   -6.214740   -0.002030         2
# 83    -8.813688   -0.014980   -4.218580         1
# 105   -9.602706   -7.077733   -0.000912         2
# 27    -0.000254   -8.326942  -11.339816         0
# 64    -8.467598   -0.001724   -6.494401         1

# %%
sql_output.Decision.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Decision, dtype: int64

# %% [markdown]
# ## Scikit-learn Prediction

# %%
skl_outputs = pd.DataFrame()
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['KEY']);
skl_output_score = pd.DataFrame(columns=['Score_0', 'Score_1', 'Score_2']);
skl_output_proba = pd.DataFrame(clf.predict_proba(X), columns=['Proba_0', 'Proba_1', 'Proba_2'])
skl_output_log_proba = pd.DataFrame(clf.predict_log_proba(X), columns=['LogProba_0', 'LogProba_1', 'LogProba_2'])
skl_output_decision = pd.DataFrame(clf.predict(X), columns=['Decision'])
skl_output = pd.concat([skl_output_key, skl_output_score, skl_output_proba, skl_output_log_proba, skl_output_decision] , axis=1)
skl_output.sample(12, random_state=1960)
# Out:
#      KEY Score_0 Score_1 Score_2   Proba_0   Proba_1   Proba_2  LogProba_0  \
# 114  114     NaN     NaN     NaN  0.000010  0.000328  0.999662  -11.484658
# 74    74     NaN     NaN     NaN  0.000020  0.999900  0.000081  -10.839005
# 9      9     NaN     NaN     NaN  0.999519  0.000469  0.000012   -0.000481
# 88    88     NaN     NaN     NaN  0.000121  0.998281  0.001599   -9.021603
# 25    25     NaN     NaN     NaN  0.999720  0.000268  0.000012   -0.000280
# 5      5     NaN     NaN     NaN  0.999758  0.000234  0.000008   -0.000242
# 48    48     NaN     NaN     NaN  0.999700  0.000293  0.000006   -0.000300
# 117  117     NaN     NaN     NaN  0.000028  0.002000  0.997972  -10.469335
# 83    83     NaN     NaN     NaN  0.000149  0.985132  0.014720   -8.813688
# 105  105     NaN     NaN     NaN  0.000068  0.000844  0.999089   -9.602706
# 27    27     NaN     NaN     NaN  0.999746  0.000242  0.000012   -0.000254
# 64    64     NaN     NaN     NaN  0.000210  0.998278  0.001512   -8.467598
#
#      LogProba_1  LogProba_2  Decision
# 114   -8.023285   -0.000338         2
# 74    -0.000100   -9.424720         1
# 9     -7.664672  -11.336026         0
# 88    -0.001721   -6.438685         1
# 25    -8.225346  -11.335825         0
# 5     -8.362051  -11.728128         0
# 48    -8.134236  -11.970501         0
# 117   -6.214740   -0.002030         2
# 83    -0.014980   -4.218580         1
# 105   -7.077733   -0.000912         2
# 27    -8.326942  -11.339816         0
# 64    -0.001724   -6.494401         1

# %% [markdown]
# ## Comparing the SQL and Scikit-learn Predictions

# %%
sql_skl_join = skl_output.join(sql_output , how='left', on='KEY', lsuffix='_skl', rsuffix='_sql')

# %%
sql_skl_join.sample(12, random_state=1960)
# Out:
#      KEY_skl Score_0_skl Score_1_skl Score_2_skl  Proba_0_skl  Proba_1_skl  \
# 114      114         NaN         NaN         NaN     0.000010     0.000328
# 74        74         NaN         NaN         NaN     0.000020     0.999900
# 9          9         NaN         NaN         NaN     0.999519     0.000469
# 88        88         NaN         NaN         NaN     0.000121     0.998281
# 25        25         NaN         NaN         NaN     0.999720     0.000268
# 5          5         NaN         NaN         NaN     0.999758     0.000234
# 48        48         NaN         NaN         NaN     0.999700     0.000293
# 117      117         NaN         NaN         NaN     0.000028     0.002000
# 83        83         NaN         NaN         NaN     0.000149     0.985132
# 105      105         NaN         NaN         NaN     0.000068     0.000844
# 27        27         NaN         NaN         NaN     0.999746     0.000242
# 64        64         NaN         NaN         NaN     0.000210     0.998278
#
#      Proba_2_skl  LogProba_0_skl  LogProba_1_skl  LogProba_2_skl  \
# 114     0.999662      -11.484658       -8.023285       -0.000338
# 74      0.000081      -10.839005       -0.000100       -9.424720
# 9       0.000012       -0.000481       -7.664672      -11.336026
# 88      0.001599       -9.021603       -0.001721       -6.438685
# 25      0.000012       -0.000280       -8.225346      -11.335825
# 5       0.000008       -0.000242       -8.362051      -11.728128
# 48      0.000006       -0.000300       -8.134236      -11.970501
# 117     0.997972      -10.469335       -6.214740       -0.002030
# 83      0.014720       -8.813688       -0.014980       -4.218580
# 105     0.999089       -9.602706       -7.077733       -0.000912
# 27      0.000012       -0.000254       -8.326942      -11.339816
# 64      0.001512       -8.467598       -0.001724       -6.494401
#
#          ...       Score_0_sql  Score_1_sql  Score_2_sql  Proba_0_sql  \
# 114      ...         -5.847731    -2.386357     5.636589     0.000010
# 74       ...         -5.949027     4.889878    -4.534741     0.000020
# 9        ...          7.360130    -0.304061    -3.975415     0.999519
# 88       ...         -5.896455     3.123427    -3.313537     0.000121
# 25       ...          7.360130    -0.864936    -3.975415     0.999720
# 5        ...          7.300883    -1.060926    -4.427003     0.999758
# 48       ...          7.300883    -0.833054    -4.669319     0.999700
# 117      ...         -5.883144    -1.628549     4.584161     0.000028
# 83       ...         -5.864954     2.933755    -1.269846     0.000149
# 105      ...         -5.873120    -3.348146     3.728675     0.000068
# 27       ...          7.300883    -1.025805    -4.038679     0.999746
# 64       ...         -5.901081     2.564793    -3.927885     0.000210
#
#      Proba_1_sql  Proba_2_sql  LogProba_0_sql  LogProba_1_sql  LogProba_2_sql  \
# 114     0.000328     0.999662      -11.484658       -8.023285       -0.000338
# 74      0.999900     0.000081      -10.839005       -0.000100       -9.424720
# 9       0.000469     0.000012       -0.000481       -7.664672      -11.336026
# 88      0.998281     0.001599       -9.021603       -0.001721       -6.438685
# 25      0.000268     0.000012       -0.000280       -8.225346      -11.335825
# 5       0.000234     0.000008       -0.000242       -8.362051      -11.728128
# 48      0.000293     0.000006       -0.000300       -8.134236      -11.970501
# 117     0.002000     0.997972      -10.469335       -6.214740       -0.002030
# 83      0.985132     0.014720       -8.813688       -0.014980       -4.218580
# 105     0.000844     0.999089       -9.602706       -7.077733       -0.000912
# 27      0.000242     0.000012       -0.000254       -8.326942      -11.339816
# 64      0.998278     0.001512       -8.467598       -0.001724       -6.494401
#
#      Decision_sql
# 114             2
# 74              1
# 9               0
# 88              1
# 25              0
# 5               0
# 48              0
# 117             2
# 83              1
# 105             2
# 27              0
# 64              1
#
# [12 rows x 22 columns]

# %%
condition = (sql_skl_join.Decision_sql != sql_skl_join.Decision_skl)
sql_skl_join[condition]
# Out:
# Empty DataFrame
# Columns: [KEY_skl, Score_0_skl, Score_1_skl, Score_2_skl, Proba_0_skl, Proba_1_skl, Proba_2_skl, LogProba_0_skl, LogProba_1_skl, LogProba_2_skl, Decision_skl, KEY_sql, Score_0_sql, Score_1_sql, Score_2_sql, Proba_0_sql, Proba_1_sql, Proba_2_sql, LogProba_0_sql, LogProba_1_sql, LogProba_2_sql, Decision_sql]
# Index: []
#
# [0 rows x 22 columns]
