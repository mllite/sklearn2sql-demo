# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa
import pickle, json, requests, base64

# %% [markdown]
# ## Build a scikit-learn model

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data  
Y = iris.target
# print(iris.DESCR)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X, Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
#clf.__dict__

# %% [markdown]
# ## Generate SQL Code from the Model

# %%
def test_ws_sql_gen(pickle_data):
    WS_URL="http://192.168.88.88:1888/model"
    b64_data = base64.b64encode(pickle_data)
    data={"Name":"model1", "PickleData":b64_data , "SQLDialect":"postgresql"}
    r = requests.post(WS_URL, json=data)
    content = r.json()
    # print(content)
    lSQL = content["model"]["SQLGenrationResult"][0]["SQL"]
    return lSQL;

# %%
pickle_data = pickle.dumps(clf)
lSQL = test_ws_sql_gen(pickle_data)
print(lSQL[0:2000])
# Out:
# WITH "DT_node_data" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values"."Proba_0" AS "Proba_0", "Values"."LogProba_0" AS "LogProba_0", "Values"."Proba_1" AS "Proba_1", "Values"."LogProba_1" AS "LogProba_1", "Values"."Proba_2" AS "Proba_2", "Values"."LogProba_2" AS "LogProba_2", "Values"."Decision" AS "Decision"
# FROM (SELECT 0 AS node_id, 'Feature_2' AS feature, 2.450000047683716 AS threshold, 150 AS count, 0 AS depth, 0.3333333333333333 AS "Proba_0", -1.09861228867 AS "LogProba_0", 0.3333333333333333 AS "Proba_1", -1.09861228867 AS "LogProba_1", 0.3333333333333333 AS "Proba_2", -1.09861228867 AS "LogProba_2", 0 AS "Decision" UNION ALL SELECT 1 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 50 AS count, 1 AS depth, 1.0 AS "Proba_0", 0.0 AS "LogProba_0", 0.0 AS "Proba_1", -1.79769313486231e+308 AS "LogProba_1", 0.0 AS "Proba_2", -1.79769313486231e+308 AS "LogProba_2", 0 AS "Decision" UNION ALL SELECT 2 AS node_id, 'Feature_3' AS feature, 1.75 AS threshold, 100 AS count, 1 AS depth, 0.0 AS "Proba_0", -1.79769313486231e+308 AS "LogProba_0", 0.5 AS "Proba_1", -0.69314718056 AS "LogProba_1", 0.5 AS "Proba_2", -0.69314718056 AS "LogProba_2", 1 AS "Decision" UNION ALL SELECT 3 AS node_id, 'Feature_2' AS feature, 4.949999809265137 AS threshold, 54 AS count, 2 AS depth, 0.0 AS "Proba_0", -1.79769313486231e+308 AS "LogProba_0", 0.9074074074074074 AS "Proba_1", -0.0971637484536 AS "LogProba_1", 0.09259259259259259 AS "Proba_2", -2.37954613413 AS "LogProba_2", 1 AS "Decision" UNION ALL SELECT 4 AS node_id, 'Feature_3' AS feature, 1.6500000953674316 AS threshold, 48 AS count, 3 AS depth, 0.0 AS "Proba_0", -1.79769313486231e+308 AS "LogProba_0", 0.9791666666666666 AS "Proba_1", -0.0210534091978 AS "LogProba_1", 0.020833333333333332 AS "Proba_2", -3.87120101091 AS "LogProba_2", 1 AS "Decision" UNION ALL SELECT 5 AS node_id, CAST(NULL A

# %% [markdown]
# ## Execute the SQL Code

# %%
# save the dataset in a database table

#engine = sa.create_engine('sqlite://' , echo=False)
engine = sa.create_engine("postgresql://db:db@localhost/db?port=5432", echo=False)
conn = engine.connect()

lTable = pd.DataFrame(X);
lTable.columns = ['Feature_0', 'Feature_1', 'Feature_2', 'Feature_3']
lTable['KEY'] = range(lTable.shape[0])
lTable.to_sql("INPUT_DATA" , conn,   if_exists='replace', index=False)

# %%
sql_output = pd.read_sql(lSQL , conn);

# %%
sql_output.sample(12)
# Out:
#      KEY Score_0 Score_1 Score_2  Proba_0  Proba_1  Proba_2     LogProba_0  \
# 128  128    None    None    None      0.0      0.0      1.0 -1.797693e+308
# 45    45    None    None    None      1.0      0.0      0.0   0.000000e+00
# 87    87    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 78    78    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 16    16    None    None    None      1.0      0.0      0.0   0.000000e+00
# 0      0    None    None    None      1.0      0.0      0.0   0.000000e+00
# 112  112    None    None    None      0.0      0.0      1.0 -1.797693e+308
# 9      9    None    None    None      1.0      0.0      0.0   0.000000e+00
# 13    13    None    None    None      1.0      0.0      0.0   0.000000e+00
# 59    59    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 54    54    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 61    61    None    None    None      0.0      1.0      0.0 -1.797693e+308
#
#         LogProba_1     LogProba_2  Decision
# 128 -1.797693e+308   0.000000e+00         2
# 45  -1.797693e+308 -1.797693e+308         0
# 87    0.000000e+00 -1.797693e+308         1
# 78    0.000000e+00 -1.797693e+308         1
# 16  -1.797693e+308 -1.797693e+308         0
# 0   -1.797693e+308 -1.797693e+308         0
# 112 -1.797693e+308   0.000000e+00         2
# 9   -1.797693e+308 -1.797693e+308         0
# 13  -1.797693e+308 -1.797693e+308         0
# 59    0.000000e+00 -1.797693e+308         1
# 54    0.000000e+00 -1.797693e+308         1
# 61    0.000000e+00 -1.797693e+308         1

# %%
sql_output.Decision.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Decision, dtype: int64

# %% [markdown]
# ## Scikit-learn Prediction

# %%
skl_outputs = pd.DataFrame()
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['KEY']);
skl_output_score = pd.DataFrame(columns=['Score_0', 'Score_1', 'Score_2']);
skl_output_proba = pd.DataFrame(clf.predict_proba(X), columns=['Proba_0', 'Proba_1', 'Proba_2'])
skl_output_log_proba = pd.DataFrame(clf.predict_log_proba(X), columns=['LogProba_0', 'LogProba_1', 'LogProba_2'])
skl_output_decision = pd.DataFrame(clf.predict(X), columns=['Decision'])
skl_output = pd.concat([skl_output_key, skl_output_score, skl_output_proba, skl_output_log_proba, skl_output_decision] , axis=1)
skl_output.sample(12)
# Out:
# /usr/lib/python3/dist-packages/sklearn/tree/tree.py:791: RuntimeWarning: divide by zero encountered in log
#   return np.log(proba)
#      KEY Score_0 Score_1 Score_2  Proba_0  Proba_1  Proba_2  LogProba_0  \
# 33    33     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 125  125     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 92    92     NaN     NaN     NaN      0.0      1.0      0.0        -inf
# 135  135     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 95    95     NaN     NaN     NaN      0.0      1.0      0.0        -inf
# 102  102     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 148  148     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 59    59     NaN     NaN     NaN      0.0      1.0      0.0        -inf
# 46    46     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 110  110     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 126  126     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 3      3     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
#
#      LogProba_1  LogProba_2  Decision
# 33         -inf        -inf         0
# 125        -inf    0.000000         2
# 92     0.000000        -inf         1
# 135        -inf    0.000000         2
# 95     0.000000        -inf         1
# 102        -inf    0.000000         2
# 148        -inf    0.000000         2
# 59     0.000000        -inf         1
# 46         -inf        -inf         0
# 110        -inf    0.000000         2
# 126        -inf    0.000000         2
# 3          -inf        -inf         0

# %% [markdown]
# ## Comparing the SQL and Scikit-learn Predictions

# %%
sql_skl_join = skl_output.join(sql_output , how='left', on='KEY', lsuffix='_skl', rsuffix='_sql')

# %%
sql_skl_join.sample(12)
# Out:
#      KEY_skl Score_0_skl Score_1_skl Score_2_skl  Proba_0_skl  Proba_1_skl  \
# 85        85         NaN         NaN         NaN          0.0          1.0
# 72        72         NaN         NaN         NaN          0.0          1.0
# 123      123         NaN         NaN         NaN          0.0          0.0
# 5          5         NaN         NaN         NaN          1.0          0.0
# 16        16         NaN         NaN         NaN          1.0          0.0
# 105      105         NaN         NaN         NaN          0.0          0.0
# 76        76         NaN         NaN         NaN          0.0          1.0
# 119      119         NaN         NaN         NaN          0.0          0.0
# 49        49         NaN         NaN         NaN          1.0          0.0
# 29        29         NaN         NaN         NaN          1.0          0.0
# 68        68         NaN         NaN         NaN          0.0          1.0
# 28        28         NaN         NaN         NaN          1.0          0.0
#
#      Proba_2_skl  LogProba_0_skl  LogProba_1_skl  LogProba_2_skl  \
# 85           0.0            -inf        0.000000            -inf
# 72           0.0            -inf        0.000000            -inf
# 123          1.0            -inf            -inf        0.000000
# 5            0.0        0.000000            -inf            -inf
# 16           0.0        0.000000            -inf            -inf
# 105          1.0            -inf            -inf        0.000000
# 76           0.0            -inf        0.000000            -inf
# 119          1.0            -inf            -inf        0.000000
# 49           0.0        0.000000            -inf            -inf
# 29           0.0        0.000000            -inf            -inf
# 68           0.0            -inf        0.000000            -inf
# 28           0.0        0.000000            -inf            -inf
#
#          ...       Score_0_sql  Score_1_sql Score_2_sql Proba_0_sql  \
# 85       ...              None         None        None         0.0
# 72       ...              None         None        None         0.0
# 123      ...              None         None        None         0.0
# 5        ...              None         None        None         1.0
# 16       ...              None         None        None         1.0
# 105      ...              None         None        None         0.0
# 76       ...              None         None        None         0.0
# 119      ...              None         None        None         0.0
# 49       ...              None         None        None         1.0
# 29       ...              None         None        None         1.0
# 68       ...              None         None        None         0.0
# 28       ...              None         None        None         1.0
#
#     Proba_1_sql  Proba_2_sql  LogProba_0_sql  LogProba_1_sql  LogProba_2_sql  \
# 85          1.0          0.0  -1.797693e+308    0.000000e+00  -1.797693e+308
# 72          1.0          0.0  -1.797693e+308    0.000000e+00  -1.797693e+308
# 123         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 5           0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
# 16          0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
# 105         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 76          1.0          0.0  -1.797693e+308    0.000000e+00  -1.797693e+308
# 119         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 49          0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
# 29          0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
# 68          1.0          0.0  -1.797693e+308    0.000000e+00  -1.797693e+308
# 28          0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
#
#      Decision_sql
# 85              1
# 72              1
# 123             2
# 5               0
# 16              0
# 105             2
# 76              1
# 119             2
# 49              0
# 29              0
# 68              1
# 28              0
#
# [12 rows x 22 columns]

# %%
condition = (sql_skl_join.Decision_sql != sql_skl_join.Decision_skl)
sql_skl_join[condition]
# Out:
# Empty DataFrame
# Columns: [KEY_skl, Score_0_skl, Score_1_skl, Score_2_skl, Proba_0_skl, Proba_1_skl, Proba_2_skl, LogProba_0_skl, LogProba_1_skl, LogProba_2_skl, Decision_skl, KEY_sql, Score_0_sql, Score_1_sql, Score_2_sql, Proba_0_sql, Proba_1_sql, Proba_2_sql, LogProba_0_sql, LogProba_1_sql, LogProba_2_sql, Decision_sql]
# Index: []
#
# [0 rows x 22 columns]
