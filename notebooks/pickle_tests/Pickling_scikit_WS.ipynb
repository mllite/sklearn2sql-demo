# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa
import pickle, json, requests, base64

# %% [markdown]
# ## Build a scikit-learn model

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data  
Y = iris.target
# print(iris.DESCR)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X, Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
#clf.__dict__

# %% [markdown]
# ## Generate SQL Code from the Model

# %%
def test_ws_sql_gen(pickle_data):
    WS_URL="http://192.168.88.88:1888/model"
    b64_data = base64.b64encode(pickle_data)
    data={"Name":"model1", "PickleData":b64_data , "SQLDialect":"postgresql"}
    r = requests.post(WS_URL, json=data)
    content = r.json()
    # print(content)
    lSQL = content["model"]["SQLGenrationResult"][0]["SQL"]
    return lSQL;

# %%
pickle_data = pickle.dumps(clf)
lSQL = test_ws_sql_gen(pickle_data)
print(lSQL[0:2000])
# Out:
# WITH "DT_node_lookup" AS
# (SELECT "ADS"."KEY" AS "KEY", CASE WHEN ("ADS"."Feature_2" <= 2.450000047683716) THEN 1 ELSE CASE WHEN ("ADS"."Feature_3" <= 1.75) THEN CASE WHEN ("ADS"."Feature_2" <= 4.949999809265137) THEN CASE WHEN ("ADS"."Feature_3" <= 1.6500000953674316) THEN 5 ELSE 6 END ELSE CASE WHEN ("ADS"."Feature_3" <= 1.5499999523162842) THEN 8 ELSE CASE WHEN ("ADS"."Feature_2" <= 5.449999809265137) THEN 10 ELSE 11 END END END ELSE CASE WHEN ("ADS"."Feature_2" <= 4.850000381469727) THEN CASE WHEN ("ADS"."Feature_1" <= 3.0999999046325684) THEN 14 ELSE 15 END ELSE 16 END END END AS node_id_2
# FROM "INPUT_DATA" AS "ADS"),
# "DT_node_data" AS
# (SELECT "Values".node_id AS node_id, "Values".feature AS feature, "Values".threshold AS threshold, "Values".count AS count, "Values".depth AS depth, "Values".parent_id AS parent_id, "Values"."Proba_0" AS "Proba_0", "Values"."LogProba_0" AS "LogProba_0", "Values"."Proba_1" AS "Proba_1", "Values"."LogProba_1" AS "LogProba_1", "Values"."Proba_2" AS "Proba_2", "Values"."LogProba_2" AS "LogProba_2", "Values"."Decision" AS "Decision"
# FROM (SELECT 0 AS node_id, 'Feature_2' AS feature, 2.450000047683716 AS threshold, 150 AS count, 0 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.3333333333333333 AS "Proba_0", -1.09861228867 AS "LogProba_0", 0.3333333333333333 AS "Proba_1", -1.09861228867 AS "LogProba_1", 0.3333333333333333 AS "Proba_2", -1.09861228867 AS "LogProba_2", 0 AS "Decision" UNION ALL SELECT 1 AS node_id, CAST(NULL AS VARCHAR(256)) AS feature, CAST(NULL AS FLOAT) AS threshold, 50 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 1.0 AS "Proba_0", 0.0 AS "LogProba_0", 0.0 AS "Proba_1", -1.79769313486231e+308 AS "LogProba_1", 0.0 AS "Proba_2", -1.79769313486231e+308 AS "LogProba_2", 0 AS "Decision" UNION ALL SELECT 2 AS node_id, 'Feature_3' AS feature, 1.75 AS threshold, 100 AS count, 1 AS depth, CAST(NULL AS INTEGER) AS parent_id, 0.0 AS "Proba_0", -1.79769313486231e+308 AS "LogProba_0", 0.5 AS "Proba_1", -0.69314718

# %% [markdown]
# ## Execute the SQL Code

# %%
# save the dataset in a database table

#engine = sa.create_engine('sqlite://' , echo=False)
engine = sa.create_engine("postgresql://db:db@localhost/db?port=5432", echo=False)
conn = engine.connect()

lTable = pd.DataFrame(X);
lTable.columns = ['Feature_0', 'Feature_1', 'Feature_2', 'Feature_3']
lTable['KEY'] = range(lTable.shape[0])
lTable.to_sql("INPUT_DATA" , conn,   if_exists='replace', index=False)

# %%
sql_output = pd.read_sql(lSQL , conn);

# %%
sql_output.sample(12)
# Out:
#      KEY Score_0 Score_1 Score_2  Proba_0  Proba_1  Proba_2     LogProba_0  \
# 97    97    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 96    96    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 136  136    None    None    None      0.0      0.0      1.0 -1.797693e+308
# 118  118    None    None    None      0.0      0.0      1.0 -1.797693e+308
# 72    72    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 26    26    None    None    None      1.0      0.0      0.0   0.000000e+00
# 83    83    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 102  102    None    None    None      0.0      0.0      1.0 -1.797693e+308
# 74    74    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 64    64    None    None    None      0.0      1.0      0.0 -1.797693e+308
# 110  110    None    None    None      0.0      0.0      1.0 -1.797693e+308
# 31    31    None    None    None      1.0      0.0      0.0   0.000000e+00
#
#         LogProba_1     LogProba_2  Decision
# 97    0.000000e+00 -1.797693e+308         1
# 96    0.000000e+00 -1.797693e+308         1
# 136 -1.797693e+308   0.000000e+00         2
# 118 -1.797693e+308   0.000000e+00         2
# 72    0.000000e+00 -1.797693e+308         1
# 26  -1.797693e+308 -1.797693e+308         0
# 83    0.000000e+00 -1.797693e+308         1
# 102 -1.797693e+308   0.000000e+00         2
# 74    0.000000e+00 -1.797693e+308         1
# 64    0.000000e+00 -1.797693e+308         1
# 110 -1.797693e+308   0.000000e+00         2
# 31  -1.797693e+308 -1.797693e+308         0

# %%
sql_output.Decision.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Decision, dtype: int64

# %% [markdown]
# ## Scikit-learn Prediction

# %%
skl_outputs = pd.DataFrame()
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['KEY']);
skl_output_score = pd.DataFrame(columns=['Score_0', 'Score_1', 'Score_2']);
skl_output_proba = pd.DataFrame(clf.predict_proba(X), columns=['Proba_0', 'Proba_1', 'Proba_2'])
skl_output_log_proba = pd.DataFrame(clf.predict_log_proba(X), columns=['LogProba_0', 'LogProba_1', 'LogProba_2'])
skl_output_decision = pd.DataFrame(clf.predict(X), columns=['Decision'])
skl_output = pd.concat([skl_output_key, skl_output_score, skl_output_proba, skl_output_log_proba, skl_output_decision] , axis=1)
skl_output.sample(12)
# Out:
# /usr/lib/python3/dist-packages/sklearn/tree/tree.py:791: RuntimeWarning: divide by zero encountered in log
#   return np.log(proba)
#      KEY Score_0 Score_1 Score_2  Proba_0  Proba_1  Proba_2  LogProba_0  \
# 29    29     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 128  128     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 124  124     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 39    39     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 45    45     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 10    10     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 30    30     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 63    63     NaN     NaN     NaN      0.0      1.0      0.0        -inf
# 67    67     NaN     NaN     NaN      0.0      1.0      0.0        -inf
# 112  112     NaN     NaN     NaN      0.0      0.0      1.0        -inf
# 13    13     NaN     NaN     NaN      1.0      0.0      0.0    0.000000
# 54    54     NaN     NaN     NaN      0.0      1.0      0.0        -inf
#
#      LogProba_1  LogProba_2  Decision
# 29         -inf        -inf         0
# 128        -inf    0.000000         2
# 124        -inf    0.000000         2
# 39         -inf        -inf         0
# 45         -inf        -inf         0
# 10         -inf        -inf         0
# 30         -inf        -inf         0
# 63     0.000000        -inf         1
# 67     0.000000        -inf         1
# 112        -inf    0.000000         2
# 13         -inf        -inf         0
# 54     0.000000        -inf         1

# %% [markdown]
# ## Comparing the SQL and Scikit-learn Predictions

# %%
sql_skl_join = skl_output.join(sql_output , how='left', on='KEY', lsuffix='_skl', rsuffix='_sql')

# %%
sql_skl_join.sample(12)
# Out:
#      KEY_skl Score_0_skl Score_1_skl Score_2_skl  Proba_0_skl  Proba_1_skl  \
# 114      114         NaN         NaN         NaN          0.0          0.0
# 106      106         NaN         NaN         NaN          0.0          0.0
# 134      134         NaN         NaN         NaN          0.0          0.0
# 113      113         NaN         NaN         NaN          0.0          0.0
# 54        54         NaN         NaN         NaN          0.0          1.0
# 78        78         NaN         NaN         NaN          0.0          1.0
# 40        40         NaN         NaN         NaN          1.0          0.0
# 18        18         NaN         NaN         NaN          1.0          0.0
# 107      107         NaN         NaN         NaN          0.0          0.0
# 102      102         NaN         NaN         NaN          0.0          0.0
# 99        99         NaN         NaN         NaN          0.0          1.0
# 32        32         NaN         NaN         NaN          1.0          0.0
#
#      Proba_2_skl  LogProba_0_skl  LogProba_1_skl  LogProba_2_skl  \
# 114          1.0            -inf            -inf        0.000000
# 106          1.0            -inf            -inf        0.000000
# 134          1.0            -inf            -inf        0.000000
# 113          1.0            -inf            -inf        0.000000
# 54           0.0            -inf        0.000000            -inf
# 78           0.0            -inf        0.000000            -inf
# 40           0.0        0.000000            -inf            -inf
# 18           0.0        0.000000            -inf            -inf
# 107          1.0            -inf            -inf        0.000000
# 102          1.0            -inf            -inf        0.000000
# 99           0.0            -inf        0.000000            -inf
# 32           0.0        0.000000            -inf            -inf
#
#          ...       Score_0_sql  Score_1_sql Score_2_sql Proba_0_sql  \
# 114      ...              None         None        None         0.0
# 106      ...              None         None        None         0.0
# 134      ...              None         None        None         0.0
# 113      ...              None         None        None         0.0
# 54       ...              None         None        None         0.0
# 78       ...              None         None        None         0.0
# 40       ...              None         None        None         1.0
# 18       ...              None         None        None         1.0
# 107      ...              None         None        None         0.0
# 102      ...              None         None        None         0.0
# 99       ...              None         None        None         0.0
# 32       ...              None         None        None         1.0
#
#     Proba_1_sql  Proba_2_sql  LogProba_0_sql  LogProba_1_sql  LogProba_2_sql  \
# 114         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 106         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 134         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 113         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 54          1.0          0.0  -1.797693e+308    0.000000e+00  -1.797693e+308
# 78          1.0          0.0  -1.797693e+308    0.000000e+00  -1.797693e+308
# 40          0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
# 18          0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
# 107         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 102         0.0          1.0  -1.797693e+308  -1.797693e+308    0.000000e+00
# 99          1.0          0.0  -1.797693e+308    0.000000e+00  -1.797693e+308
# 32          0.0          0.0    0.000000e+00  -1.797693e+308  -1.797693e+308
#
#      Decision_sql
# 114             2
# 106             2
# 134             2
# 113             2
# 54              1
# 78              1
# 40              0
# 18              0
# 107             2
# 102             2
# 99              1
# 32              0
#
# [12 rows x 22 columns]

# %%
condition = (sql_skl_join.Decision_sql != sql_skl_join.Decision_skl)
sql_skl_join[condition]
# Out:
# Empty DataFrame
# Columns: [KEY_skl, Score_0_skl, Score_1_skl, Score_2_skl, Proba_0_skl, Proba_1_skl, Proba_2_skl, LogProba_0_skl, LogProba_1_skl, LogProba_2_skl, Decision_skl, KEY_sql, Score_0_sql, Score_1_sql, Score_2_sql, Proba_0_sql, Proba_1_sql, Proba_2_sql, LogProba_0_sql, LogProba_1_sql, LogProba_2_sql, Decision_sql]
# Index: []
#
# [0 rows x 22 columns]
