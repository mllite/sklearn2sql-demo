# %%
import numpy as np
import pandas as pd
import sqlalchemy as sa
import pickle, json, requests, base64

# %% [markdown]
# ## Build a scikit-learn model

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data  
Y = iris.target
# print(iris.DESCR)

# %%
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.decomposition import PCA
from sklearn.preprocessing import Imputer, StandardScaler, MinMaxScaler
from sklearn.preprocessing import RobustScaler, MaxAbsScaler

from sklearn.pipeline import FeatureUnion

imputers = [('imputer', Imputer())]
scalers =  [('std_scaler', StandardScaler()), ('minmax_scaler', MinMaxScaler()),
            ('maxabs_scaler', MaxAbsScaler()), ('robust_scaler', RobustScaler())];
pcas = [('pca_4comps', PCA(n_components = 4))]
random_state = np.random.RandomState(0)
clf = FeatureUnion(scalers + pcas)

clf.fit(X, Y)
# Out:
# FeatureUnion(n_jobs=1,
#        transformer_list=[('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('minmax_scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('maxabs_scaler', MaxAbsScaler(copy=True)), ('robust_scaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('pca_4comps', PCA(copy=True, iterated_power='auto', n_components=4, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False))],
#        transformer_weights=None)

# %%
#clf.__dict__

# %% [markdown]
# ## Generate SQL Code from the Model

# %%
def test_ws_sql_gen(pickle_data):
    WS_URL="http://192.168.88.88:1888/model" # "https://sklearn2sql.herokuapp.com/"
    b64_data = base64.b64encode(pickle_data)
    data={"Name":"model1", "PickleData":b64_data , "SQLDialect":"postgresql"}
    r = requests.post(WS_URL, json=data)
    content = r.json()
    # print(content)
    lSQL = content["model"]["SQLGenrationResult"][0]["SQL"]
    return lSQL;

# %%
pickle_data = pickle.dumps(clf)
lSQL = test_ws_sql_gen(pickle_data)
print(lSQL[0:12000])
# Out:
# WITH "std_scaler_CTE" AS
# (SELECT "ADS"."KEY" AS join_key_0, (CAST("ADS"."Feature_0" AS FLOAT) - 5.84333333333) / 0.825301291785 AS std_scaler_output_1, (CAST("ADS"."Feature_1" AS FLOAT) - 3.054) / 0.432146580071 AS std_scaler_output_2, (CAST("ADS"."Feature_2" AS FLOAT) - 3.75866666667) / 1.75852918341 AS std_scaler_output_3, (CAST("ADS"."Feature_3" AS FLOAT) - 1.19866666667) / 0.760612618588 AS std_scaler_output_4
# FROM "INPUT_DATA" AS "ADS"),
# "minmax_scaler_CTE" AS
# (SELECT "ADS"."KEY" AS join_key_1, "ADS"."Feature_0" * 0.277777777778 + -1.19444444444 AS minmax_scaler_output_1, "ADS"."Feature_1" * 0.416666666667 + -0.833333333333 AS minmax_scaler_output_2, "ADS"."Feature_2" * 0.169491525424 + -0.169491525424 AS minmax_scaler_output_3, "ADS"."Feature_3" * 0.416666666667 + -0.0416666666667 AS minmax_scaler_output_4
# FROM "INPUT_DATA" AS "ADS"),
# "maxabs_scaler_CTE" AS
# (SELECT "ADS"."KEY" AS join_key_2, CAST("ADS"."Feature_0" AS FLOAT) / 7.9 AS maxabs_scaler_output_1, CAST("ADS"."Feature_1" AS FLOAT) / 4.4 AS maxabs_scaler_output_2, CAST("ADS"."Feature_2" AS FLOAT) / 6.9 AS maxabs_scaler_output_3, CAST("ADS"."Feature_3" AS FLOAT) / 2.5 AS maxabs_scaler_output_4
# FROM "INPUT_DATA" AS "ADS"),
# "robust_scaler_CTE" AS
# (SELECT "ADS"."KEY" AS join_key_3, (CAST("ADS"."Feature_0" AS FLOAT) - 5.8) / 1.3 AS robust_scaler_output_1, (CAST("ADS"."Feature_1" AS FLOAT) - 3.0) / 0.5 AS robust_scaler_output_2, (CAST("ADS"."Feature_2" AS FLOAT) - 4.35) / 3.5 AS robust_scaler_output_3, (CAST("ADS"."Feature_3" AS FLOAT) - 1.3) / 1.5 AS robust_scaler_output_4
# FROM "INPUT_DATA" AS "ADS"),
# "CenteredDataForPCA" AS
# (SELECT "ADS"."KEY" AS "KEY", "ADS"."Feature_0" - 5.84333333333 AS "Feature_0", "ADS"."Feature_1" - 3.054 AS "Feature_1", "ADS"."Feature_2" - 3.75866666667 AS "Feature_2", "ADS"."Feature_3" - 1.19866666667 AS "Feature_3"
# FROM "INPUT_DATA" AS "ADS"),
# "pca_4comps_CTE" AS
# (SELECT "CenteredDataForPCA"."KEY" AS join_key_4, "CenteredDataForPCA"."Feature_0" * 0.361589677381 + "CenteredDataForPCA"."Feature_1" * -0.0822688898922 + "CenteredDataForPCA"."Feature_2" * 0.856572105291 + "CenteredDataForPCA"."Feature_3" * 0.358843926248 AS pca_4comps_output_1, "CenteredDataForPCA"."Feature_0" * 0.656539883286 + "CenteredDataForPCA"."Feature_1" * 0.729712371326 + "CenteredDataForPCA"."Feature_2" * -0.175767403429 + "CenteredDataForPCA"."Feature_3" * -0.074706470135 AS pca_4comps_output_2, "CenteredDataForPCA"."Feature_0" * -0.580997279828 + "CenteredDataForPCA"."Feature_1" * 0.596418087938 + "CenteredDataForPCA"."Feature_2" * 0.072524075487 + "CenteredDataForPCA"."Feature_3" * 0.549060910727 AS pca_4comps_output_3, "CenteredDataForPCA"."Feature_0" * 0.317254547169 + "CenteredDataForPCA"."Feature_1" * -0.324094352418 + "CenteredDataForPCA"."Feature_2" * -0.47971898733 + "CenteredDataForPCA"."Feature_3" * 0.751120560381 AS pca_4comps_output_4
# FROM "CenteredDataForPCA"),
# "Feature_Join_CTE" AS
# (SELECT "std_scaler_CTE".join_key_0 AS join_key_0, "std_scaler_CTE".std_scaler_output_1 AS std_scaler_output_1, "std_scaler_CTE".std_scaler_output_2 AS std_scaler_output_2, "std_scaler_CTE".std_scaler_output_3 AS std_scaler_output_3, "std_scaler_CTE".std_scaler_output_4 AS std_scaler_output_4, "minmax_scaler_CTE".join_key_1 AS join_key_1, "minmax_scaler_CTE".minmax_scaler_output_1 AS minmax_scaler_output_1, "minmax_scaler_CTE".minmax_scaler_output_2 AS minmax_scaler_output_2, "minmax_scaler_CTE".minmax_scaler_output_3 AS minmax_scaler_output_3, "minmax_scaler_CTE".minmax_scaler_output_4 AS minmax_scaler_output_4, "maxabs_scaler_CTE".join_key_2 AS join_key_2, "maxabs_scaler_CTE".maxabs_scaler_output_1 AS maxabs_scaler_output_1, "maxabs_scaler_CTE".maxabs_scaler_output_2 AS maxabs_scaler_output_2, "maxabs_scaler_CTE".maxabs_scaler_output_3 AS maxabs_scaler_output_3, "maxabs_scaler_CTE".maxabs_scaler_output_4 AS maxabs_scaler_output_4, "robust_scaler_CTE".join_key_3 AS join_key_3, "robust_scaler_CTE".robust_scaler_output_1 AS robust_scaler_output_1, "robust_scaler_CTE".robust_scaler_output_2 AS robust_scaler_output_2, "robust_scaler_CTE".robust_scaler_output_3 AS robust_scaler_output_3, "robust_scaler_CTE".robust_scaler_output_4 AS robust_scaler_output_4, "pca_4comps_CTE".join_key_4 AS join_key_4, "pca_4comps_CTE".pca_4comps_output_1 AS pca_4comps_output_1, "pca_4comps_CTE".pca_4comps_output_2 AS pca_4comps_output_2, "pca_4comps_CTE".pca_4comps_output_3 AS pca_4comps_output_3, "pca_4comps_CTE".pca_4comps_output_4 AS pca_4comps_output_4
# FROM "std_scaler_CTE" LEFT OUTER JOIN "minmax_scaler_CTE" ON "std_scaler_CTE".join_key_0 = "minmax_scaler_CTE".join_key_1 LEFT OUTER JOIN "maxabs_scaler_CTE" ON "maxabs_scaler_CTE".join_key_2 = "minmax_scaler_CTE".join_key_1 LEFT OUTER JOIN "robust_scaler_CTE" ON "robust_scaler_CTE".join_key_3 = "maxabs_scaler_CTE".join_key_2 LEFT OUTER JOIN "pca_4comps_CTE" ON "pca_4comps_CTE".join_key_4 = "robust_scaler_CTE".join_key_3)
#  SELECT "Feature_Join_CTE".join_key_0 AS "KEY", "Feature_Join_CTE".std_scaler_output_1 AS std_scaler_output_1, "Feature_Join_CTE".std_scaler_output_2 AS std_scaler_output_2, "Feature_Join_CTE".std_scaler_output_3 AS std_scaler_output_3, "Feature_Join_CTE".std_scaler_output_4 AS std_scaler_output_4, "Feature_Join_CTE".minmax_scaler_output_1 AS minmax_scaler_output_1, "Feature_Join_CTE".minmax_scaler_output_2 AS minmax_scaler_output_2, "Feature_Join_CTE".minmax_scaler_output_3 AS minmax_scaler_output_3, "Feature_Join_CTE".minmax_scaler_output_4 AS minmax_scaler_output_4, "Feature_Join_CTE".maxabs_scaler_output_1 AS maxabs_scaler_output_1, "Feature_Join_CTE".maxabs_scaler_output_2 AS maxabs_scaler_output_2, "Feature_Join_CTE".maxabs_scaler_output_3 AS maxabs_scaler_output_3, "Feature_Join_CTE".maxabs_scaler_output_4 AS maxabs_scaler_output_4, "Feature_Join_CTE".robust_scaler_output_1 AS robust_scaler_output_1, "Feature_Join_CTE".robust_scaler_output_2 AS robust_scaler_output_2, "Feature_Join_CTE".robust_scaler_output_3 AS robust_scaler_output_3, "Feature_Join_CTE".robust_scaler_output_4 AS robust_scaler_output_4, "Feature_Join_CTE".pca_4comps_output_1 AS pca_4comps_output_1, "Feature_Join_CTE".pca_4comps_output_2 AS pca_4comps_output_2, "Feature_Join_CTE".pca_4comps_output_3 AS pca_4comps_output_3, "Feature_Join_CTE".pca_4comps_output_4 AS pca_4comps_output_4
# FROM "Feature_Join_CTE"

# %% [markdown]
# ## Execute the SQL Code

# %%
# save the dataset in a database table

#engine = sa.create_engine('sqlite://' , echo=False)
engine = sa.create_engine("postgresql://db:db@localhost/db?port=5432", echo=False)
conn = engine.connect()

lTable = pd.DataFrame(X);
lTable.columns = ['Feature_0', 'Feature_1', 'Feature_2', 'Feature_3']
lTable['KEY'] = range(lTable.shape[0])
lTable.to_sql("INPUT_DATA" , conn,   if_exists='replace', index=False)

# %%
sql_output = pd.read_sql(lSQL , conn);
sql_output = sql_output.sort_values(by='KEY').reset_index(drop=True)

# %%
sql_output.sample(12, random_state=1960)
# Out:
#      KEY  std_scaler_output_1  std_scaler_output_2  std_scaler_output_3  \
# 114  114            -0.052506            -0.587764             0.762759
# 74    74             0.674501            -0.356361             0.307833
# 9      9            -1.143017             0.106445            -1.284407
# 88    88            -0.294842            -0.124958             0.194102
# 25    25            -1.021849            -0.124958            -1.227541
# 5      5            -0.537178             1.957669            -1.170675
# 48    48            -0.658345             1.494863            -1.284407
# 117  117             2.249683             1.726266             1.672610
# 83    83             0.189830            -0.819166             0.762759
# 105  105             2.128516            -0.124958             1.615744
# 27    27            -0.779513             1.032057            -1.284407
# 64    64            -0.294842            -0.356361            -0.090227
#
#      std_scaler_output_4  minmax_scaler_output_1  minmax_scaler_output_2  \
# 114             1.579429                0.416667                0.333333
# 74              0.133226                0.583333                0.375000
# 9              -1.444450                0.166667                0.458333
# 88              0.133226                0.361111                0.416667
# 25             -1.312977                0.194444                0.416667
# 5              -1.050031                0.305556                0.791667
# 48             -1.312977                0.277778                0.708333
# 117             1.316483                0.944444                0.750000
# 83              0.527645                0.472222                0.291667
# 105             1.185010                0.916667                0.416667
# 27             -1.312977                0.250000                0.625000
# 64              0.133226                0.361111                0.375000
#
#      minmax_scaler_output_3  minmax_scaler_output_4  maxabs_scaler_output_1  \
# 114                0.694915                0.958333                0.734177
# 74                 0.559322                0.500000                0.810127
# 9                  0.084746                0.000000                0.620253
# 88                 0.525424                0.500000                0.708861
# 25                 0.101695                0.041667                0.632911
# 5                  0.118644                0.125000                0.683544
# 48                 0.084746                0.041667                0.670886
# 117                0.966102                0.875000                0.974684
# 83                 0.694915                0.625000                0.759494
# 105                0.949153                0.833333                0.962025
# 27                 0.084746                0.041667                0.658228
# 64                 0.440678                0.500000                0.708861
#
#             ...           maxabs_scaler_output_3  maxabs_scaler_output_4  \
# 114         ...                         0.739130                    0.96
# 74          ...                         0.623188                    0.52
# 9           ...                         0.217391                    0.04
# 88          ...                         0.594203                    0.52
# 25          ...                         0.231884                    0.08
# 5           ...                         0.246377                    0.16
# 48          ...                         0.217391                    0.08
# 117         ...                         0.971014                    0.88
# 83          ...                         0.739130                    0.64
# 105         ...                         0.956522                    0.84
# 27          ...                         0.217391                    0.08
# 64          ...                         0.521739                    0.52
#
#      robust_scaler_output_1  robust_scaler_output_2  robust_scaler_output_3  \
# 114                0.000000                    -0.4                0.214286
# 74                 0.461538                    -0.2               -0.014286
# 9                 -0.692308                     0.2               -0.814286
# 88                -0.153846                     0.0               -0.071429
# 25                -0.615385                     0.0               -0.785714
# 5                 -0.307692                     1.8               -0.757143
# 48                -0.384615                     1.4               -0.814286
# 117                1.461538                     1.6                0.671429
# 83                 0.153846                    -0.6                0.214286
# 105                1.384615                     0.0                0.642857
# 27                -0.461538                     1.0               -0.814286
# 64                -0.153846                    -0.2               -0.214286
#
#      robust_scaler_output_4  pca_4comps_output_1  pca_4comps_output_2  \
# 114                0.733333             1.585267            -0.539307
# 74                 0.000000             0.714008             0.150379
# 9                 -0.800000            -2.673845            -0.106692
# 88                 0.000000             0.245195            -0.266728
# 25                -0.733333            -2.507917            -0.139056
# 5                 -0.600000            -2.279897             0.747783
# 48                -0.733333            -2.542686             0.586281
# 117                0.600000             3.488765             1.171545
# 83                 0.200000             1.378737            -0.421205
# 105                0.533333             3.396880             0.547168
# 27                -0.733333            -2.562391             0.374685
# 64                 0.000000            -0.174864            -0.251816
#
#      pca_4comps_output_3  pca_4comps_output_4
# 114             0.630570             0.327455
# 74             -0.320372             0.042941
# 9              -0.191533            -0.055891
# 88              0.189562            -0.147328
# 25             -0.247116             0.035384
# 5               0.174326            -0.027147
# 48             -0.011175            -0.048334
# 117             0.129320            -0.311630
# 83              0.015480            -0.177581
# 105            -0.351873            -0.111220
# 27             -0.072359            -0.015240
# 64              0.093659             0.124941
#
# [12 rows x 21 columns]

# %%
sql_output.describe()
# Out:
#               KEY  std_scaler_output_1  std_scaler_output_2  \
# count  150.000000         1.500000e+02         1.500000e+02
# mean    74.500000         4.038062e-12         5.447494e-16
# std     43.445368         1.003350e+00         1.003350e+00
# min      0.000000        -1.870024e+00        -2.438987e+00
# 25%     37.250000        -9.006812e-01        -5.877635e-01
# 50%     74.500000        -5.250608e-02        -1.249576e-01
# 75%    111.750000         6.745011e-01         5.692513e-01
# max    149.000000         2.492019e+00         3.114684e+00
#
#        std_scaler_output_3  std_scaler_output_4  minmax_scaler_output_1  \
# count         1.500000e+02         1.500000e+02            1.500000e+02
# mean         -1.895539e-12        -4.381680e-12            4.287037e-01
# std           1.003350e+00         1.003350e+00            2.300184e-01
# min          -1.568735e+00        -1.444450e+00            5.399903e-12
# 25%          -1.227541e+00        -1.181504e+00            2.222222e-01
# 50%           3.362659e-01         1.332259e-01            4.166667e-01
# 75%           7.627586e-01         7.905908e-01            5.833333e-01
# max           1.786341e+00         1.710902e+00            1.000000e+00
#
#        minmax_scaler_output_2  minmax_scaler_output_3  minmax_scaler_output_4  \
# count            1.500000e+02              150.000000              150.000000
# mean             4.391667e-01                0.467571                0.457778
# std              1.806643e-01                0.299054                0.317984
# min              9.999779e-13                0.000000                0.000000
# 25%              3.333333e-01                0.101695                0.083333
# 50%              4.166667e-01                0.567797                0.500000
# 75%              5.416667e-01                0.694915                0.708333
# max              1.000000e+00                1.000000                1.000000
#
#        maxabs_scaler_output_1         ...           maxabs_scaler_output_3  \
# count              150.000000         ...                       150.000000
# mean                 0.739662         ...                         0.544734
# std                  0.104818         ...                         0.255713
# min                  0.544304         ...                         0.144928
# 25%                  0.645570         ...                         0.231884
# 50%                  0.734177         ...                         0.630435
# 75%                  0.810127         ...                         0.739130
# max                  1.000000         ...                         1.000000
#
#        maxabs_scaler_output_4  robust_scaler_output_1  robust_scaler_output_2  \
# count              150.000000              150.000000              150.000000
# mean                 0.479467                0.033333                0.108000
# std                  0.305264                0.636974                0.867189
# min                  0.040000               -1.153846               -2.000000
# 25%                  0.120000               -0.538462               -0.400000
# 50%                  0.520000                0.000000                0.000000
# 75%                  0.720000                0.461538                0.600000
# max                  1.000000                1.615385                2.800000
#
#        robust_scaler_output_3  robust_scaler_output_4  pca_4comps_output_1  \
# count            1.500000e+02              150.000000         1.500000e+02
# mean            -1.689524e-01               -0.067556        -2.844634e-12
# std              5.041201e-01                0.508774         2.055442e+00
# min             -9.571429e-01               -0.800000        -3.225200e+00
# 25%             -7.857143e-01               -0.666667        -2.530159e+00
# 50%              1.500536e-16                0.000000         5.533290e-01
# 75%              2.142857e-01                0.333333         1.549463e+00
# max              7.285714e-01                0.800000         3.794687e+00
#
#        pca_4comps_output_2  pca_4comps_output_3  pca_4comps_output_4
# count         1.500000e+02         1.500000e+02         1.500000e+02
# mean          3.023324e-12        -4.008334e-12         1.526192e-13
# std           4.921825e-01         2.802212e-01         1.538929e-01
# min          -1.262492e+00        -6.919416e-01        -5.035295e-01
# 25%          -3.235986e-01        -2.027230e-01        -7.618597e-02
# 50%          -3.251102e-02         1.557634e-02        -4.322010e-04
# 75%           3.288601e-01         1.780586e-01         8.895186e-02
# max           1.370524e+00         7.584587e-01         5.040950e-01
#
# [8 rows x 21 columns]

# %% [markdown]
# ## Scikit-learn Prediction

# %%
skl_outputs = pd.DataFrame()
skl_output_key = pd.DataFrame(list(range(X.shape[0])), columns=['KEY']);
skl_output_FU = pd.DataFrame(clf.transform(X))
skl_output = pd.concat([skl_output_key, skl_output_FU] , axis=1)
# sklearn does not provide column names ;)
skl_output.columns = sql_output.columns
skl_output.sample(12, random_state=1960)
# Out:
#      KEY  std_scaler_output_1  std_scaler_output_2  std_scaler_output_3  \
# 114  114            -0.052506            -0.587764             0.762759
# 74    74             0.674501            -0.356361             0.307833
# 9      9            -1.143017             0.106445            -1.284407
# 88    88            -0.294842            -0.124958             0.194102
# 25    25            -1.021849            -0.124958            -1.227541
# 5      5            -0.537178             1.957669            -1.170675
# 48    48            -0.658345             1.494863            -1.284407
# 117  117             2.249683             1.726266             1.672610
# 83    83             0.189830            -0.819166             0.762759
# 105  105             2.128516            -0.124958             1.615744
# 27    27            -0.779513             1.032057            -1.284407
# 64    64            -0.294842            -0.356361            -0.090227
#
#      std_scaler_output_4  minmax_scaler_output_1  minmax_scaler_output_2  \
# 114             1.579429                0.416667                0.333333
# 74              0.133226                0.583333                0.375000
# 9              -1.444450                0.166667                0.458333
# 88              0.133226                0.361111                0.416667
# 25             -1.312977                0.194444                0.416667
# 5              -1.050031                0.305556                0.791667
# 48             -1.312977                0.277778                0.708333
# 117             1.316483                0.944444                0.750000
# 83              0.527645                0.472222                0.291667
# 105             1.185010                0.916667                0.416667
# 27             -1.312977                0.250000                0.625000
# 64              0.133226                0.361111                0.375000
#
#      minmax_scaler_output_3  minmax_scaler_output_4  maxabs_scaler_output_1  \
# 114                0.694915                0.958333                0.734177
# 74                 0.559322                0.500000                0.810127
# 9                  0.084746                0.000000                0.620253
# 88                 0.525424                0.500000                0.708861
# 25                 0.101695                0.041667                0.632911
# 5                  0.118644                0.125000                0.683544
# 48                 0.084746                0.041667                0.670886
# 117                0.966102                0.875000                0.974684
# 83                 0.694915                0.625000                0.759494
# 105                0.949153                0.833333                0.962025
# 27                 0.084746                0.041667                0.658228
# 64                 0.440678                0.500000                0.708861
#
#             ...           maxabs_scaler_output_3  maxabs_scaler_output_4  \
# 114         ...                         0.739130                    0.96
# 74          ...                         0.623188                    0.52
# 9           ...                         0.217391                    0.04
# 88          ...                         0.594203                    0.52
# 25          ...                         0.231884                    0.08
# 5           ...                         0.246377                    0.16
# 48          ...                         0.217391                    0.08
# 117         ...                         0.971014                    0.88
# 83          ...                         0.739130                    0.64
# 105         ...                         0.956522                    0.84
# 27          ...                         0.217391                    0.08
# 64          ...                         0.521739                    0.52
#
#      robust_scaler_output_1  robust_scaler_output_2  robust_scaler_output_3  \
# 114                0.000000                    -0.4                0.214286
# 74                 0.461538                    -0.2               -0.014286
# 9                 -0.692308                     0.2               -0.814286
# 88                -0.153846                     0.0               -0.071429
# 25                -0.615385                     0.0               -0.785714
# 5                 -0.307692                     1.8               -0.757143
# 48                -0.384615                     1.4               -0.814286
# 117                1.461538                     1.6                0.671429
# 83                 0.153846                    -0.6                0.214286
# 105                1.384615                     0.0                0.642857
# 27                -0.461538                     1.0               -0.814286
# 64                -0.153846                    -0.2               -0.214286
#
#      robust_scaler_output_4  pca_4comps_output_1  pca_4comps_output_2  \
# 114                0.733333             1.585267            -0.539307
# 74                 0.000000             0.714008             0.150379
# 9                 -0.800000            -2.673845            -0.106692
# 88                 0.000000             0.245195            -0.266728
# 25                -0.733333            -2.507917            -0.139056
# 5                 -0.600000            -2.279897             0.747783
# 48                -0.733333            -2.542686             0.586281
# 117                0.600000             3.488765             1.171545
# 83                 0.200000             1.378737            -0.421205
# 105                0.533333             3.396880             0.547168
# 27                -0.733333            -2.562391             0.374685
# 64                 0.000000            -0.174864            -0.251816
#
#      pca_4comps_output_3  pca_4comps_output_4
# 114             0.630570             0.327455
# 74             -0.320372             0.042941
# 9              -0.191533            -0.055891
# 88              0.189562            -0.147328
# 25             -0.247116             0.035384
# 5               0.174326            -0.027147
# 48             -0.011175            -0.048334
# 117             0.129320            -0.311630
# 83              0.015480            -0.177581
# 105            -0.351873            -0.111220
# 27             -0.072359            -0.015240
# 64              0.093659             0.124941
#
# [12 rows x 21 columns]

# %% [markdown]
# ## Comparing the SQL and Scikit-learn Predictions

# %%
sql_skl_join = skl_output.join(sql_output , how='left', on='KEY', lsuffix='_skl', rsuffix='_sql')

# %%
sql_skl_join.sample(12, random_state=1960)
# Out:
#      KEY_skl  std_scaler_output_1_skl  std_scaler_output_2_skl  \
# 114      114                -0.052506                -0.587764
# 74        74                 0.674501                -0.356361
# 9          9                -1.143017                 0.106445
# 88        88                -0.294842                -0.124958
# 25        25                -1.021849                -0.124958
# 5          5                -0.537178                 1.957669
# 48        48                -0.658345                 1.494863
# 117      117                 2.249683                 1.726266
# 83        83                 0.189830                -0.819166
# 105      105                 2.128516                -0.124958
# 27        27                -0.779513                 1.032057
# 64        64                -0.294842                -0.356361
#
#      std_scaler_output_3_skl  std_scaler_output_4_skl  \
# 114                 0.762759                 1.579429
# 74                  0.307833                 0.133226
# 9                  -1.284407                -1.444450
# 88                  0.194102                 0.133226
# 25                 -1.227541                -1.312977
# 5                  -1.170675                -1.050031
# 48                 -1.284407                -1.312977
# 117                 1.672610                 1.316483
# 83                  0.762759                 0.527645
# 105                 1.615744                 1.185010
# 27                 -1.284407                -1.312977
# 64                 -0.090227                 0.133226
#
#      minmax_scaler_output_1_skl  minmax_scaler_output_2_skl  \
# 114                    0.416667                    0.333333
# 74                     0.583333                    0.375000
# 9                      0.166667                    0.458333
# 88                     0.361111                    0.416667
# 25                     0.194444                    0.416667
# 5                      0.305556                    0.791667
# 48                     0.277778                    0.708333
# 117                    0.944444                    0.750000
# 83                     0.472222                    0.291667
# 105                    0.916667                    0.416667
# 27                     0.250000                    0.625000
# 64                     0.361111                    0.375000
#
#      minmax_scaler_output_3_skl  minmax_scaler_output_4_skl  \
# 114                    0.694915                    0.958333
# 74                     0.559322                    0.500000
# 9                      0.084746                    0.000000
# 88                     0.525424                    0.500000
# 25                     0.101695                    0.041667
# 5                      0.118644                    0.125000
# 48                     0.084746                    0.041667
# 117                    0.966102                    0.875000
# 83                     0.694915                    0.625000
# 105                    0.949153                    0.833333
# 27                     0.084746                    0.041667
# 64                     0.440678                    0.500000
#
#      maxabs_scaler_output_1_skl           ...             \
# 114                    0.734177           ...
# 74                     0.810127           ...
# 9                      0.620253           ...
# 88                     0.708861           ...
# 25                     0.632911           ...
# 5                      0.683544           ...
# 48                     0.670886           ...
# 117                    0.974684           ...
# 83                     0.759494           ...
# 105                    0.962025           ...
# 27                     0.658228           ...
# 64                     0.708861           ...
#
#      maxabs_scaler_output_3_sql  maxabs_scaler_output_4_sql  \
# 114                    0.739130                        0.96
# 74                     0.623188                        0.52
# 9                      0.217391                        0.04
# 88                     0.594203                        0.52
# 25                     0.231884                        0.08
# 5                      0.246377                        0.16
# 48                     0.217391                        0.08
# 117                    0.971014                        0.88
# 83                     0.739130                        0.64
# 105                    0.956522                        0.84
# 27                     0.217391                        0.08
# 64                     0.521739                        0.52
#
#      robust_scaler_output_1_sql  robust_scaler_output_2_sql  \
# 114                    0.000000                        -0.4
# 74                     0.461538                        -0.2
# 9                     -0.692308                         0.2
# 88                    -0.153846                         0.0
# 25                    -0.615385                         0.0
# 5                     -0.307692                         1.8
# 48                    -0.384615                         1.4
# 117                    1.461538                         1.6
# 83                     0.153846                        -0.6
# 105                    1.384615                         0.0
# 27                    -0.461538                         1.0
# 64                    -0.153846                        -0.2
#
#      robust_scaler_output_3_sql  robust_scaler_output_4_sql  \
# 114                    0.214286                    0.733333
# 74                    -0.014286                    0.000000
# 9                     -0.814286                   -0.800000
# 88                    -0.071429                    0.000000
# 25                    -0.785714                   -0.733333
# 5                     -0.757143                   -0.600000
# 48                    -0.814286                   -0.733333
# 117                    0.671429                    0.600000
# 83                     0.214286                    0.200000
# 105                    0.642857                    0.533333
# 27                    -0.814286                   -0.733333
# 64                    -0.214286                    0.000000
#
#      pca_4comps_output_1_sql  pca_4comps_output_2_sql  \
# 114                 1.585267                -0.539307
# 74                  0.714008                 0.150379
# 9                  -2.673845                -0.106692
# 88                  0.245195                -0.266728
# 25                 -2.507917                -0.139056
# 5                  -2.279897                 0.747783
# 48                 -2.542686                 0.586281
# 117                 3.488765                 1.171545
# 83                  1.378737                -0.421205
# 105                 3.396880                 0.547168
# 27                 -2.562391                 0.374685
# 64                 -0.174864                -0.251816
#
#      pca_4comps_output_3_sql  pca_4comps_output_4_sql
# 114                 0.630570                 0.327455
# 74                 -0.320372                 0.042941
# 9                  -0.191533                -0.055891
# 88                  0.189562                -0.147328
# 25                 -0.247116                 0.035384
# 5                   0.174326                -0.027147
# 48                 -0.011175                -0.048334
# 117                 0.129320                -0.311630
# 83                  0.015480                -0.177581
# 105                -0.351873                -0.111220
# 27                 -0.072359                -0.015240
# 64                  0.093659                 0.124941
#
# [12 rows x 42 columns]

# %%
errors_df = pd.DataFrame()
#errors_df['KEY'] = sql_skl_join['KEY_sql']
for col in sql_output.columns:
    errors_df[col + '_Error'] = sql_skl_join[col + '_skl'] - sql_skl_join[col + '_sql']

errors_df.describe()
# Out:
#        KEY_Error  std_scaler_output_1_Error  std_scaler_output_2_Error  \
# count      150.0               1.500000e+02               1.500000e+02
# mean         0.0              -4.039568e-12              -2.216930e-15
# std          0.0               1.719557e-13               1.059488e-12
# min          0.0              -4.463097e-12              -2.581935e-12
# 25%          0.0              -4.155232e-12              -6.230572e-13
# 50%          0.0              -4.031046e-12              -1.343509e-13
# 75%          0.0              -3.885892e-12               5.996315e-13
# max          0.0              -3.720135e-12               3.284484e-12
#
#        std_scaler_output_3_Error  std_scaler_output_4_Error  \
# count               1.500000e+02               1.500000e+02
# mean                1.894043e-12               4.380969e-12
# std                 2.556504e-12               2.264527e-13
# min                -2.103429e-12               3.998135e-12
# 25%                -1.229239e-12               4.202749e-12
# 50%                 2.750911e-12               4.351602e-12
# 75%                 3.837486e-12               4.648282e-12
# max                 6.446621e-12               4.711120e-12
#
#        minmax_scaler_output_1_Error  minmax_scaler_output_2_Error  \
# count                  1.500000e+02                  1.500000e+02
# mean                  -5.742985e-12                 -1.351365e-12
# std                    1.840046e-13                  1.445515e-13
# min                   -6.199929e-12                 -1.799894e-12
# 25%                   -5.866529e-12                 -1.433520e-12
# 50%                   -5.733469e-12                 -1.333267e-12
# 75%                   -5.577899e-12                 -1.266764e-12
# max                   -5.399903e-12                 -9.999779e-13
#
#        minmax_scaler_output_3_Error  minmax_scaler_output_4_Error  \
# count                  1.500000e+02                  1.500000e+02
# mean                  -7.481284e-13                 -3.661886e-13
# std                    4.784936e-13                  2.543710e-13
# min                   -1.600053e-12                 -8.000267e-13
# 25%                   -1.111888e-12                 -5.666578e-13
# 50%                   -9.084955e-13                 -3.999023e-13
# 75%                   -1.627032e-13                 -6.666889e-14
# max                    0.000000e+00                  0.000000e+00
#
#        maxabs_scaler_output_1_Error            ...              \
# count                  1.500000e+02            ...
# mean                   3.922788e-17            ...
# std                    2.833115e-16            ...
# min                   -4.440892e-16            ...
# 25%                   -2.220446e-16            ...
# 50%                    1.110223e-16            ...
# 75%                    3.330669e-16            ...
# max                    4.440892e-16            ...
#
#        maxabs_scaler_output_3_Error  maxabs_scaler_output_4_Error  \
# count                  1.500000e+02                  1.500000e+02
# mean                   3.423188e-17                 -5.551115e-18
# std                    2.852798e-16                  4.758764e-17
# min                   -4.440892e-16                 -1.110223e-16
# 25%                   -3.330669e-16                  0.000000e+00
# 50%                    8.326673e-17                  0.000000e+00
# 75%                    2.636780e-16                  0.000000e+00
# max                    4.996004e-16                  1.110223e-16
#
#        robust_scaler_output_1_Error  robust_scaler_output_2_Error  \
# count                  1.500000e+02                  1.500000e+02
# mean                  -2.137179e-17                 -1.554312e-17
# std                    1.084674e-15                  2.765570e-16
# min                   -5.107026e-15                 -8.881784e-16
# 25%                   -4.579670e-16                 -2.220446e-16
# 50%                   -1.387779e-17                  0.000000e+00
# 75%                    3.330669e-16                  2.081668e-16
# max                    3.996803e-15                  8.881784e-16
#
#        robust_scaler_output_3_Error  robust_scaler_output_4_Error  \
# count                  1.500000e+02                  1.500000e+02
# mean                   9.598803e-18                 -4.866478e-17
# std                    2.586577e-16                  2.938771e-16
# min                   -5.551115e-16                 -4.440892e-16
# 25%                   -1.665335e-16                 -3.885781e-16
# 50%                   -1.040834e-17                 -1.387779e-17
# 75%                    2.220446e-16                  3.053113e-16
# max                    4.996004e-16                  3.330669e-16
#
#        pca_4comps_output_1_Error  pca_4comps_output_2_Error  \
# count               1.500000e+02               1.500000e+02
# mean                2.841861e-12              -3.024171e-12
# std                 3.892743e-13               4.075556e-13
# min                 2.137401e-12              -3.991807e-12
# 25%                 2.549128e-12              -3.392038e-12
# 50%                 2.721628e-12              -2.978465e-12
# 75%                 3.210654e-12              -2.722336e-12
# max                 3.800515e-12              -1.986189e-12
#
#        pca_4comps_output_3_Error  pca_4comps_output_4_Error
# count               1.500000e+02               1.500000e+02
# mean                4.008147e-12              -1.519275e-13
# std                 2.284275e-13               4.026851e-13
# min                 3.363976e-12              -1.062095e-12
# 25%                 3.857432e-12              -4.567093e-13
# 50%                 3.997318e-12              -1.337038e-13
# 75%                 4.189968e-12               2.191199e-13
# max                 4.579198e-12               5.906768e-13
#
# [8 rows x 21 columns]
